# %%
import pandas as pd
import numpy as np
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt


from pandas_profiling import ProfileReport
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_excel("train.xlsx")
test_data = pd.read_excel('test.xlsx')
train_data, validation_data = train_test_split(train_data, test_size = 0.3)

# %%
train = train_data.set_index('CITIZEN_ID')
# Split Titles from the name. Titles will then be converted to gender.
train.insert(2,'Gender','')
train[['Gender','Name']] = train['Name'].str.split(' ', n=1, expand = True)
# Check unique titles
train['Gender'].unique()
# Replace with binary 1 = male 0 = female
train['Gender'] = train['Gender'].replace(['Mr.','Miss','Mrs.'],[1,0,1]).astype(np.uint8)

# %%
# Age
train.insert(2,'Year','')
train['Year'] = train['Birthday'].str.strip().str[-4:]
train['Year'] = train['Year'].astype(int)
train.insert(2,'Age','')
train['Age'] = 2048-train['Year']

train = train.drop(['Name','Birthday','Year'], axis = 1)

# %%
train.isin(['?']).sum(axis=0)
# Out:
# Age                         0
# Gender                      0
# Native Continent            0
# Marital Status              0
# Lives with                  0
# Base Area                 264
# Education Level             0
# Years of Education          0
# Employment Sector         851
# Role                      856
# Working Hours per week      0
# Money Received              0
# Ticket Price                0
# Income                      0
# dtype: int64

# %%
train = train[train['Base Area'] != '?']
train = train[train['Employment Sector'] != '?']
train = train[train['Role'] != '?']

# %%
# Work related features
train.insert(10,'Emp Role','')
train["Emp Role"] = train["Employment Sector"] + train["Role"]
train.insert(10,'Base Emp','')
train["Base Emp"] = train["Base Area"] + train["Employment Sector"]
train.insert(10,'Base Role','')
train["Base Role"] = train["Base Area"] + train["Role"]

# %%
train.shape
# Out:
# (14573, 17)

# %%
# Ticket and Money received binary
train.insert(16,'Ticket Bi','')
train['Ticket Bi'] = train['Ticket Price'].astype(bool).astype(np.uint8)
train.insert(16,'Money Bi','')
train['Money Bi'] = train['Money Received'].astype(bool).astype(np.uint8)

# %%
# Check number of 0 before binary
train.isin([0]).sum(axis=0)
# Out:
# Age                           0
# Gender                     2135
# Native Continent              0
# Marital Status                0
# Lives with                    0
# Base Area                     0
# Education Level               0
# Years of Education            0
# Employment Sector             0
# Role                          0
# Base Role                     0
# Base Emp                      0
# Emp Role                      0
# Working Hours per week        0
# Money Received            13339
# Ticket Price              13869
# Money Bi                  13339
# Ticket Bi                 13869
# Income                    10992
# dtype: int64

# %%
train.head(5)
# Out:
#             Age  Gender Native Continent Marital Status       Lives with  \
# CITIZEN_ID
# 14626        43       1           Europe       Divorced  Other relatives
# 20880        53       0           Europe         Single     Other Family
# 31427        62       1           Europe          Widow     Other Family
# 14909        34       1           Europe         Single     Other Family
# 22542        41       1           Africa       Divorced            Alone
#
#             Base Area               Education Level  Years of Education  \
# CITIZEN_ID
# 14626       Northbury    Bachelors + PostGraduation                  16
# 20880       Northbury           Professional School                  12
# 31427       Northbury           Professional School                  12
# 14909       Northbury  High School + PostGraduation                  13
# 22542       Northbury           Professional School                  12
#
#                      Employment Sector                            Role  \
# CITIZEN_ID
# 14626       Private Sector - Services   Machine Operators & Inspectors
# 20880       Private Sector - Services                            Sales
# 31427       Private Sector - Services                            Sales
# 14909           Public Sector - Others                        Security
# 22542       Private Sector - Services                            Sales
#
#                                           Base Role  \
# CITIZEN_ID
# 14626       NorthburyMachine Operators & Inspectors
# 20880                                NorthburySales
# 31427                                NorthburySales
# 14909                             NorthburySecurity
# 22542                                NorthburySales
#
#                                        Base Emp  \
# CITIZEN_ID
# 14626       NorthburyPrivate Sector - Services
# 20880       NorthburyPrivate Sector - Services
# 31427       NorthburyPrivate Sector - Services
# 14909           NorthburyPublic Sector - Others
# 22542       NorthburyPrivate Sector - Services
#
#                                                      Emp Role  \
# CITIZEN_ID
# 14626       Private Sector - Services Machine Operators & ...
# 20880                         Private Sector - Services Sales
# 31427                         Private Sector - Services Sales
# 14909                          Public Sector - OthersSecurity
# 22542                         Private Sector - Services Sales
#
#             Working Hours per week  Money Received  Ticket Price  Money Bi  \
# CITIZEN_ID
# 14626                           40               0             0         0
# 20880                           40               0             0         0
# 31427                           32               0             0         0
# 14909                           50               0             0         0
# 22542                           40               0             0         0
#
#             Ticket Bi  Income
# CITIZEN_ID
# 14626               0       0
# 20880               0       0
# 31427               0       0
# 14909               0       1
# 22542               0       0

# %%
train_base = train.copy()

# %%
import phik

# %%
#train.phik_matrix().to_excel('phik explore1.xlsx')

# %%
train.nunique()
# Out:
# Age                        72
# Gender                      2
# Native Continent            5
# Marital Status              7
# Lives with                  6
# Base Area                  39
# Education Level            16
# Years of Education         14
# Employment Sector           7
# Role                       14
# Base Role                 321
# Base Emp                  150
# Emp Role                   78
# Working Hours per week     93
# Money Received            106
# Ticket Price               76
# Money Bi                    2
# Ticket Bi                   2
# Income                      2
# dtype: int64

# %%
#train = train.drop(['Education Level'], axis = 1)
#train = train.drop(['Native Continent','Base Area'], axis = 1)

# %%
#Neverworked
#train.loc[train['Employment Sector'] == 'Never Worked', 'Role'] = "Never Worked"

# %%
train['Employment Sector'].unique()
# Out:
# array(['Private Sector - Services ', 'Self-Employed (Individual)',
#        'Private Sector - Others', 'Public Sector - Others',
#        'Self-Employed (Company)', 'Public Sector - Government',
#        'Unemployed'], dtype=object)

# %%
#Drop a reference variable per column if you want to actually use it.
dummies_NC = pd.get_dummies(train['Native Continent'])
dummies_MS = pd.get_dummies(train['Marital Status'])
dummies_LW = pd.get_dummies(train['Lives with'])
dummies_BA = pd.get_dummies(train['Base Area'])
dummies_EL = pd.get_dummies(train['Education Level'])
dummies_ES = pd.get_dummies(train['Employment Sector'])
dummies_Ro = pd.get_dummies(train['Role'])
dummies_BR = pd.get_dummies(train['Base Role'])
dummies_BE = pd.get_dummies(train['Base Emp'])
dummies_ER = pd.get_dummies(train['Emp Role'])

# %%
train = train.join(dummies_NC)
train = train.join(dummies_MS)
train = train.join(dummies_LW)
train = train.join(dummies_BA)
train = train.join(dummies_EL)
train = train.join(dummies_ES)
train = train.join(dummies_Ro)
train = train.join(dummies_BR)
train = train.join(dummies_BE)
train = train.join(dummies_ER)

# %%
train['Income2'] = train['Income'].astype(np.uint8)
train = train.drop(['Income'], axis = 1)
train.rename(columns={'Income2':'Income'}, inplace=True)

# %%
train = train.convert_dtypes()

# %%
train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14492 entries, 16807 to 21531
# Data columns (total 662 columns):
#  #   Column                                                    Dtype
# ---  ------                                                    -----
#  0   Age                                                       Int32
#  1   Gender                                                    UInt8
#  2   Native Continent                                          string
#  3   Marital Status                                            string
#  4   Lives with                                                string
#  5   Base Area                                                 string
#  6   Education Level                                           string
#  7   Years of Education                                        Int64
#  8   Employment Sector                                         string
#  9   Role                                                      string
#  10  Base Role                                                 string
#  11  Base Emp                                                  string
#  12  Emp Role                                                  string
#  13  Working Hours per week                                    Int64
#  14  Money Received                                            Int64
#  15  Ticket Price                                              Int64
#  16  Money Bi                                                  UInt8
#  17  Ticket Bi                                                 UInt8
#  18  Africa                                                    UInt8
#  19  America                                                   UInt8
#  20  Asia                                                      UInt8
#  21  Europe                                                    UInt8
#  22  Oceania                                                   UInt8
#  23  Divorced                                                  UInt8
#  24  Married                                                   UInt8
#  25  Married - Spouse Missing                                  UInt8
#  26  Married - Spouse in the Army                              UInt8
#  27  Separated                                                 UInt8
#  28  Single                                                    UInt8
#  29  Widow                                                     UInt8
#  30  Alone                                                     UInt8
#  31  Children                                                  UInt8
#  32  Husband                                                   UInt8
#  33  Other Family                                              UInt8
#  34  Other relatives                                           UInt8
#  35  Wife                                                      UInt8
#  36  Aberuthven                                                UInt8
#  37  Aerilon                                                   UInt8
#  38  Alverton                                                  UInt8
#  39  Aroonshire                                                UInt8
#  40  Auchenshuggle                                             UInt8
#  41  Bellenau                                                  UInt8
#  42  Bellmoral                                                 UInt8
#  43  Butterpond                                                UInt8
#  44  Carlisle                                                  UInt8
#  45  Cherrytown                                                UInt8
#  46  Conriston                                                 UInt8
#  47  Drumchapel                                                UInt8
#  48  Eelry                                                     UInt8
#  49  Fanfoss                                                   UInt8
#  50  Fool's March                                              UInt8
#  51  Ironforge                                                 UInt8
#  52  Kald                                                      UInt8
#  53  King's Watch                                              UInt8
#  54  Kirkwall                                                  UInt8
#  55  Knife's Edge                                              UInt8
#  56  Laenteglos                                                UInt8
#  57  Laewaes                                                   UInt8
#  58  Lanercost                                                 UInt8
#  59  Lewes                                                     UInt8
#  60  Marnmouth                                                 UInt8
#  61  Mensfield                                                 UInt8
#  62  Middlesbrough                                             UInt8
#  63  MillerVille                                               UInt8
#  64  Northbury                                                 UInt8
#  65  Orilon                                                    UInt8
#  66  Pran                                                      UInt8
#  67  Redwick Bush                                              UInt8
#  68  Sharnwick                                                 UInt8
#  69  Sharpton                                                  UInt8
#  70  Tranmere                                                  UInt8
#  71  Watford                                                   UInt8
#  72  Wigston                                                   UInt8
#  73  Willesden                                                 UInt8
#  74  Woodpine                                                  UInt8
#  75  Bachelors                                                 UInt8
#  76  Bachelors + PostGraduation                                UInt8
#  77  High School + PostGraduation                              UInt8
#  78  High School - 1st Cycle                                   UInt8
#  79  High School - 2nd Cycle                                   UInt8
#  80  High School Complete                                      UInt8
#  81  Masters                                                   UInt8
#  82  Masters + PostGraduation                                  UInt8
#  83  Middle School - 1st Cycle                                 UInt8
#  84  Middle School - 2nd Cycle                                 UInt8
#  85  Middle School Complete                                    UInt8
#  86  PhD                                                       UInt8
#  87  Preschool                                                 UInt8
#  88  Primary School                                            UInt8
#  89  Professional School                                       UInt8
#  90  Professional School + PostGraduation                      UInt8
#  91  Private Sector - Others                                   UInt8
#  92  Private Sector - Services                                 UInt8
#  93  Public Sector - Government                                UInt8
#  94  Public Sector - Others                                    UInt8
#  95  Self-Employed (Company)                                   UInt8
#  96  Self-Employed (Individual)                                UInt8
#  97  Unemployed                                                UInt8
#  98  Administratives                                           UInt8
#  99  Agriculture and Fishing                                   UInt8
#  100 Army                                                      UInt8
#  101 Cleaners & Handlers                                       UInt8
#  102 Household Services                                        UInt8
#  103 IT                                                        UInt8
#  104 Machine Operators & Inspectors                            UInt8
#  105 Management                                                UInt8
#  106 Other services                                            UInt8
#  107 Professor                                                 UInt8
#  108 Repair & constructions                                    UInt8
#  109 Sales                                                     UInt8
#  110 Security                                                  UInt8
#  111 Transports                                                UInt8
#  112 AberuthvenAdministratives                                 UInt8
#  113 AberuthvenCleaners & Handlers                             UInt8
#  114 AberuthvenIT                                              UInt8
#  115 AberuthvenMachine Operators & Inspectors                  UInt8
#  116 AberuthvenOther services                                  UInt8
#  117 AberuthvenProfessor                                       UInt8
#  118 AberuthvenRepair & constructions                          UInt8
#  119 AberuthvenSales                                           UInt8
#  120 AerilonAdministratives                                    UInt8
#  121 AerilonAgriculture and Fishing                            UInt8
#  122 AerilonCleaners & Handlers                                UInt8
#  123 AerilonHousehold Services                                 UInt8
#  124 AerilonIT                                                 UInt8
#  125 AerilonMachine Operators & Inspectors                     UInt8
#  126 AerilonManagement                                         UInt8
#  127 AerilonOther services                                     UInt8
#  128 AerilonProfessor                                          UInt8
#  129 AerilonRepair & constructions                             UInt8
#  130 AerilonSales                                              UInt8
#  131 AerilonTransports                                         UInt8
#  132 AlvertonAdministratives                                   UInt8
#  133 AlvertonAgriculture and Fishing                           UInt8
#  134 AlvertonCleaners & Handlers                               UInt8
#  135 AlvertonHousehold Services                                UInt8
#  136 AlvertonIT                                                UInt8
#  137 AlvertonMachine Operators & Inspectors                    UInt8
#  138 AlvertonManagement                                        UInt8
#  139 AlvertonOther services                                    UInt8
#  140 AlvertonProfessor                                         UInt8
#  141 AlvertonRepair & constructions                            UInt8
#  142 AlvertonSales                                             UInt8
#  143 AlvertonSecurity                                          UInt8
#  144 AroonshireAdministratives                                 UInt8
#  145 AroonshireCleaners & Handlers                             UInt8
#  146 AroonshireHousehold Services                              UInt8
#  147 AroonshireMachine Operators & Inspectors                  UInt8
#  148 AroonshireManagement                                      UInt8
#  149 AroonshireOther services                                  UInt8
#  150 AroonshireProfessor                                       UInt8
#  151 AroonshireRepair & constructions                          UInt8
#  152 AroonshireSales                                           UInt8
#  153 AroonshireTransports                                      UInt8
#  154 AuchenshuggleAdministratives                              UInt8
#  155 AuchenshuggleAgriculture and Fishing                      UInt8
#  156 AuchenshuggleCleaners & Handlers                          UInt8
#  157 AuchenshuggleHousehold Services                           UInt8
#  158 AuchenshuggleMachine Operators & Inspectors               UInt8
#  159 AuchenshuggleManagement                                   UInt8
#  160 AuchenshuggleOther services                               UInt8
#  161 AuchenshuggleProfessor                                    UInt8
#  162 AuchenshuggleRepair & constructions                       UInt8
#  163 AuchenshuggleSales                                        UInt8
#  164 AuchenshuggleTransports                                   UInt8
#  165 BellenauMachine Operators & Inspectors                    UInt8
#  166 BellenauManagement                                        UInt8
#  167 BellenauProfessor                                         UInt8
#  168 BellmoralAdministratives                                  UInt8
#  169 BellmoralCleaners & Handlers                              UInt8
#  170 BellmoralHousehold Services                               UInt8
#  171 BellmoralIT                                               UInt8
#  172 BellmoralMachine Operators & Inspectors                   UInt8
#  173 BellmoralManagement                                       UInt8
#  174 BellmoralOther services                                   UInt8
#  175 BellmoralProfessor                                        UInt8
#  176 BellmoralRepair & constructions                           UInt8
#  177 BellmoralSales                                            UInt8
#  178 BellmoralTransports                                       UInt8
#  179 ButterpondAdministratives                                 UInt8
#  180 ButterpondCleaners & Handlers                             UInt8
#  181 ButterpondIT                                              UInt8
#  182 ButterpondMachine Operators & Inspectors                  UInt8
#  183 ButterpondManagement                                      UInt8
#  184 ButterpondOther services                                  UInt8
#  185 ButterpondProfessor                                       UInt8
#  186 ButterpondRepair & constructions                          UInt8
#  187 ButterpondSales                                           UInt8
#  188 ButterpondSecurity                                        UInt8
#  189 ButterpondTransports                                      UInt8
#  190 CarlisleAdministratives                                   UInt8
#  191 CarlisleIT                                                UInt8
#  192 CarlisleMachine Operators & Inspectors                    UInt8
#  193 CarlisleManagement                                        UInt8
#  194 CarlisleOther services                                    UInt8
#  195 CarlisleSales                                             UInt8
#  196 CherrytownAdministratives                                 UInt8
#  197 CherrytownCleaners & Handlers                             UInt8
#  198 CherrytownHousehold Services                              UInt8
#  199 CherrytownMachine Operators & Inspectors                  UInt8
#  200 CherrytownManagement                                      UInt8
#  201 CherrytownOther services                                  UInt8
#  202 CherrytownProfessor                                       UInt8
#  203 CherrytownRepair & constructions                          UInt8
#  204 CherrytownSales                                           UInt8
#  205 CherrytownSecurity                                        UInt8
#  206 CherrytownTransports                                      UInt8
#  207 ConristonMachine Operators & Inspectors                   UInt8
#  208 ConristonManagement                                       UInt8
#  209 ConristonOther services                                   UInt8
#  210 ConristonProfessor                                        UInt8
#  211 ConristonSecurity                                         UInt8
#  212 DrumchapelCleaners & Handlers                             UInt8
#  213 DrumchapelMachine Operators & Inspectors                  UInt8
#  214 DrumchapelManagement                                      UInt8
#  215 DrumchapelRepair & constructions                          UInt8
#  216 DrumchapelSales                                           UInt8
#  217 DrumchapelSecurity                                        UInt8
#  218 EelryAdministratives                                      UInt8
#  219 EelryCleaners & Handlers                                  UInt8
#  220 EelryMachine Operators & Inspectors                       UInt8
#  221 EelryManagement                                           UInt8
#  222 EelryOther services                                       UInt8
#  223 EelryProfessor                                            UInt8
#  224 EelryRepair & constructions                               UInt8
#  225 EelrySales                                                UInt8
#  226 FanfossAdministratives                                    UInt8
#  227 FanfossAgriculture and Fishing                            UInt8
#  228 FanfossCleaners & Handlers                                UInt8
#  229 FanfossHousehold Services                                 UInt8
#  230 FanfossIT                                                 UInt8
#  231 FanfossMachine Operators & Inspectors                     UInt8
#  232 FanfossManagement                                         UInt8
#  233 FanfossOther services                                     UInt8
#  234 FanfossProfessor                                          UInt8
#  235 FanfossRepair & constructions                             UInt8
#  236 FanfossSales                                              UInt8
#  237 FanfossSecurity                                           UInt8
#  238 FanfossTransports                                         UInt8
#  239 Fool's MarchAdministratives                               UInt8
#  240 Fool's MarchAgriculture and Fishing                       UInt8
#  241 Fool's MarchCleaners & Handlers                           UInt8
#  242 Fool's MarchHousehold Services                            UInt8
#  243 Fool's MarchIT                                            UInt8
#  244 Fool's MarchMachine Operators & Inspectors                UInt8
#  245 Fool's MarchManagement                                    UInt8
#  246 Fool's MarchOther services                                UInt8
#  247 Fool's MarchProfessor                                     UInt8
#  248 Fool's MarchRepair & constructions                        UInt8
#  249 Fool's MarchSales                                         UInt8
#  250 Fool's MarchSecurity                                      UInt8
#  251 IronforgeMachine Operators & Inspectors                   UInt8
#  252 KaldAgriculture and Fishing                               UInt8
#  253 KaldHousehold Services                                    UInt8
#  254 KaldManagement                                            UInt8
#  255 KaldOther services                                        UInt8
#  256 KaldProfessor                                             UInt8
#  257 KaldSales                                                 UInt8
#  258 KaldSecurity                                              UInt8
#  259 King's WatchAdministratives                               UInt8
#  260 King's WatchAgriculture and Fishing                       UInt8
#  261 King's WatchCleaners & Handlers                           UInt8
#  262 King's WatchHousehold Services                            UInt8
#  263 King's WatchIT                                            UInt8
#  264 King's WatchMachine Operators & Inspectors                UInt8
#  265 King's WatchOther services                                UInt8
#  266 King's WatchProfessor                                     UInt8
#  267 King's WatchRepair & constructions                        UInt8
#  268 King's WatchSales                                         UInt8
#  269 King's WatchSecurity                                      UInt8
#  270 King's WatchTransports                                    UInt8
#  271 KirkwallAdministratives                                   UInt8
#  272 KirkwallAgriculture and Fishing                           UInt8
#  273 KirkwallCleaners & Handlers                               UInt8
#  274 KirkwallManagement                                        UInt8
#  275 KirkwallOther services                                    UInt8
#  276 KirkwallProfessor                                         UInt8
#  277 KirkwallRepair & constructions                            UInt8
#  278 KirkwallSales                                             UInt8
#  279 KirkwallSecurity                                          UInt8
#  280 Knife's EdgeAdministratives                               UInt8
#  281 Knife's EdgeIT                                            UInt8
#  282 Knife's EdgeManagement                                    UInt8
#  283 Knife's EdgeOther services                                UInt8
#  284 Knife's EdgeProfessor                                     UInt8
#  285 Knife's EdgeRepair & constructions                        UInt8
#  286 Knife's EdgeSales                                         UInt8
#  287 LaenteglosIT                                              UInt8
#  288 LaenteglosManagement                                      UInt8
#  289 LaenteglosOther services                                  UInt8
#  290 LaenteglosProfessor                                       UInt8
#  291 LaenteglosRepair & constructions                          UInt8
#  292 LaenteglosSales                                           UInt8
#  293 LaenteglosTransports                                      UInt8
#  294 LaewaesAdministratives                                    UInt8
#  295 LaewaesCleaners & Handlers                                UInt8
#  296 LaewaesIT                                                 UInt8
#  297 LaewaesMachine Operators & Inspectors                     UInt8
#  298 LaewaesManagement                                         UInt8
#  299 LaewaesOther services                                     UInt8
#  300 LaewaesProfessor                                          UInt8
#  301 LaewaesRepair & constructions                             UInt8
#  302 LaewaesSales                                              UInt8
#  303 LaewaesSecurity                                           UInt8
#  304 LaewaesTransports                                         UInt8
#  305 LanercostAdministratives                                  UInt8
#  306 LanercostCleaners & Handlers                              UInt8
#  307 LanercostHousehold Services                               UInt8
#  308 LanercostIT                                               UInt8
#  309 LanercostMachine Operators & Inspectors                   UInt8
#  310 LanercostManagement                                       UInt8
#  311 LanercostOther services                                   UInt8
#  312 LanercostProfessor                                        UInt8
#  313 LanercostSales                                            UInt8
#  314 LanercostTransports                                       UInt8
#  315 LewesCleaners & Handlers                                  UInt8
#  316 LewesMachine Operators & Inspectors                       UInt8
#  317 LewesManagement                                           UInt8
#  318 LewesOther services                                       UInt8
#  319 LewesProfessor                                            UInt8
#  320 LewesRepair & constructions                               UInt8
#  321 MarnmouthAdministratives                                  UInt8
#  322 MarnmouthMachine Operators & Inspectors                   UInt8
#  323 MarnmouthOther services                                   UInt8
#  324 MarnmouthRepair & constructions                           UInt8
#  325 MensfieldCleaners & Handlers                              UInt8
#  326 MensfieldManagement                                       UInt8
#  327 MensfieldOther services                                   UInt8
#  328 MensfieldRepair & constructions                           UInt8
#  329 MensfieldSales                                            UInt8
#  330 MiddlesbroughAgriculture and Fishing                      UInt8
#  331 MiddlesbroughOther services                               UInt8
#  332 MiddlesbroughProfessor                                    UInt8
#  333 MiddlesbroughRepair & constructions                       UInt8
#  334 MillerVilleAdministratives                                UInt8
#  335 MillerVilleAgriculture and Fishing                        UInt8
#  336 MillerVilleMachine Operators & Inspectors                 UInt8
#  337 MillerVilleManagement                                     UInt8
#  338 MillerVilleProfessor                                      UInt8
#  339 MillerVilleSales                                          UInt8
#  340 MillerVilleSecurity                                       UInt8
#  341 NorthburyAdministratives                                  UInt8
#  342 NorthburyAgriculture and Fishing                          UInt8
#  343 NorthburyArmy                                             UInt8
#  344 NorthburyCleaners & Handlers                              UInt8
#  345 NorthburyHousehold Services                               UInt8
#  346 NorthburyIT                                               UInt8
#  347 NorthburyMachine Operators & Inspectors                   UInt8
#  348 NorthburyManagement                                       UInt8
#  349 NorthburyOther services                                   UInt8
#  350 NorthburyProfessor                                        UInt8
#  351 NorthburyRepair & constructions                           UInt8
#  352 NorthburySales                                            UInt8
#  353 NorthburySecurity                                         UInt8
#  354 NorthburyTransports                                       UInt8
#  355 OrilonAdministratives                                     UInt8
#  356 OrilonMachine Operators & Inspectors                      UInt8
#  357 OrilonManagement                                          UInt8
#  358 OrilonOther services                                      UInt8
#  359 OrilonProfessor                                           UInt8
#  360 OrilonRepair & constructions                              UInt8
#  361 OrilonSales                                               UInt8
#  362 PranAdministratives                                       UInt8
#  363 PranAgriculture and Fishing                               UInt8
#  364 PranCleaners & Handlers                                   UInt8
#  365 PranMachine Operators & Inspectors                        UInt8
#  366 PranManagement                                            UInt8
#  367 PranOther services                                        UInt8
#  368 PranProfessor                                             UInt8
#  369 PranRepair & constructions                                UInt8
#  370 PranSales                                                 UInt8
#  371 PranSecurity                                              UInt8
#  372 PranTransports                                            UInt8
#  373 Redwick BushAdministratives                               UInt8
#  374 Redwick BushOther services                                UInt8
#  375 Redwick BushProfessor                                     UInt8
#  376 Redwick BushRepair & constructions                        UInt8
#  377 Redwick BushTransports                                    UInt8
#  378 SharnwickAdministratives                                  UInt8
#  379 SharnwickCleaners & Handlers                              UInt8
#  380 SharnwickIT                                               UInt8
#  381 SharnwickMachine Operators & Inspectors                   UInt8
#  382 SharnwickManagement                                       UInt8
#  383 SharnwickOther services                                   UInt8
#  384 SharnwickProfessor                                        UInt8
#  385 SharnwickRepair & constructions                           UInt8
#  386 SharnwickSales                                            UInt8
#  387 SharptonIT                                                UInt8
#  388 SharptonMachine Operators & Inspectors                    UInt8
#  389 SharptonManagement                                        UInt8
#  390 SharptonOther services                                    UInt8
#  391 SharptonProfessor                                         UInt8
#  392 SharptonRepair & constructions                            UInt8
#  393 SharptonSales                                             UInt8
#  394 TranmereAdministratives                                   UInt8
#  395 TranmereCleaners & Handlers                               UInt8
#  396 TranmereHousehold Services                                UInt8
#  397 TranmereMachine Operators & Inspectors                    UInt8
#  398 TranmereOther services                                    UInt8
#  399 TranmereProfessor                                         UInt8
#  400 TranmereRepair & constructions                            UInt8
#  401 TranmereSecurity                                          UInt8
#  402 TranmereTransports                                        UInt8
#  403 WatfordAdministratives                                    UInt8
#  404 WatfordAgriculture and Fishing                            UInt8
#  405 WatfordIT                                                 UInt8
#  406 WatfordMachine Operators & Inspectors                     UInt8
#  407 WatfordManagement                                         UInt8
#  408 WatfordOther services                                     UInt8
#  409 WatfordProfessor                                          UInt8
#  410 WatfordRepair & constructions                             UInt8
#  411 WatfordSales                                              UInt8
#  412 WatfordSecurity                                           UInt8
#  413 WatfordTransports                                         UInt8
#  414 WigstonAdministratives                                    UInt8
#  415 WigstonMachine Operators & Inspectors                     UInt8
#  416 WigstonManagement                                         UInt8
#  417 WigstonOther services                                     UInt8
#  418 WigstonProfessor                                          UInt8
#  419 WigstonRepair & constructions                             UInt8
#  420 WigstonSales                                              UInt8
#  421 WigstonTransports                                         UInt8
#  422 WillesdenHousehold Services                               UInt8
#  423 WillesdenIT                                               UInt8
#  424 WillesdenMachine Operators & Inspectors                   UInt8
#  425 WillesdenOther services                                   UInt8
#  426 WillesdenRepair & constructions                           UInt8
#  427 WillesdenSales                                            UInt8
#  428 WoodpineAdministratives                                   UInt8
#  429 WoodpineCleaners & Handlers                               UInt8
#  430 WoodpineManagement                                        UInt8
#  431 WoodpineOther services                                    UInt8
#  432 WoodpineSecurity                                          UInt8
#  433 AberuthvenPrivate Sector - Others                         UInt8
#  434 AberuthvenPrivate Sector - Services                       UInt8
#  435 AberuthvenPublic Sector - Others                          UInt8
#  436 AberuthvenSelf-Employed (Individual)                      UInt8
#  437 AerilonPrivate Sector - Services                          UInt8
#  438 AerilonPublic Sector - Others                             UInt8
#  439 AerilonSelf-Employed (Individual)                         UInt8
#  440 AlvertonPrivate Sector - Others                           UInt8
#  441 AlvertonPrivate Sector - Services                         UInt8
#  442 AlvertonPublic Sector - Government                        UInt8
#  443 AlvertonPublic Sector - Others                            UInt8
#  444 AlvertonUnemployed                                        UInt8
#  445 AroonshirePrivate Sector - Services                       UInt8
#  446 AroonshirePublic Sector - Government                      UInt8
#  447 AroonshirePublic Sector - Others                          UInt8
#  448 AroonshireSelf-Employed (Company)                         UInt8
#  449 AroonshireSelf-Employed (Individual)                      UInt8
#  450 AuchenshugglePrivate Sector - Services                    UInt8
#  451 AuchenshugglePublic Sector - Others                       UInt8
#  452 AuchenshuggleSelf-Employed (Individual)                   UInt8
#  453 BellenauPrivate Sector - Others                           UInt8
#  454 BellenauPrivate Sector - Services                         UInt8
#  455 BellenauSelf-Employed (Individual)                        UInt8
#  456 BellmoralPrivate Sector - Others                          UInt8
#  457 BellmoralPrivate Sector - Services                        UInt8
#  458 BellmoralPublic Sector - Government                       UInt8
#  459 BellmoralSelf-Employed (Individual)                       UInt8
#  460 ButterpondPrivate Sector - Others                         UInt8
#  461 ButterpondPrivate Sector - Services                       UInt8
#  462 ButterpondPublic Sector - Government                      UInt8
#  463 ButterpondPublic Sector - Others                          UInt8
#  464 ButterpondSelf-Employed (Company)                         UInt8
#  465 ButterpondSelf-Employed (Individual)                      UInt8
#  466 CarlislePrivate Sector - Others                           UInt8
#  467 CarlislePrivate Sector - Services                         UInt8
#  468 CarlisleSelf-Employed (Individual)                        UInt8
#  469 CherrytownPrivate Sector - Services                       UInt8
#  470 CherrytownPublic Sector - Others                          UInt8
#  471 CherrytownSelf-Employed (Company)                         UInt8
#  472 CherrytownSelf-Employed (Individual)                      UInt8
#  473 ConristonPrivate Sector - Others                          UInt8
#  474 ConristonPrivate Sector - Services                        UInt8
#  475 ConristonSelf-Employed (Individual)                       UInt8
#  476 DrumchapelPrivate Sector - Services                       UInt8
#  477 DrumchapelPublic Sector - Government                      UInt8
#  478 DrumchapelPublic Sector - Others                          UInt8
#  479 DrumchapelSelf-Employed (Company)                         UInt8
#  480 DrumchapelSelf-Employed (Individual)                      UInt8
#  481 EelryPrivate Sector - Services                            UInt8
#  482 EelryPublic Sector - Others                               UInt8
#  483 EelrySelf-Employed (Company)                              UInt8
#  484 EelrySelf-Employed (Individual)                           UInt8
#  485 FanfossPrivate Sector - Others                            UInt8
#  486 FanfossPrivate Sector - Services                          UInt8
#  487 FanfossPublic Sector - Government                         UInt8
#  488 FanfossPublic Sector - Others                             UInt8
#  489 FanfossSelf-Employed (Company)                            UInt8
#  490 FanfossSelf-Employed (Individual)                         UInt8
#  491 Fool's MarchPrivate Sector - Others                       UInt8
#  492 Fool's MarchPrivate Sector - Services                     UInt8
#  493 Fool's MarchPublic Sector - Government                    UInt8
#  494 Fool's MarchPublic Sector - Others                        UInt8
#  495 Fool's MarchSelf-Employed (Individual)                    UInt8
#  496 IronforgePrivate Sector - Services                        UInt8
#  497 KaldPrivate Sector - Services                             UInt8
#  498 KaldPublic Sector - Others                                UInt8
#  499 KaldSelf-Employed (Company)                               UInt8
#  500 King's WatchPrivate Sector - Services                     UInt8
#  501 King's WatchPublic Sector - Government                    UInt8
#  502 King's WatchPublic Sector - Others                        UInt8
#  503 KirkwallPrivate Sector - Services                         UInt8
#  504 KirkwallPublic Sector - Government                        UInt8
#  505 KirkwallPublic Sector - Others                            UInt8
#  506 KirkwallSelf-Employed (Individual)                        UInt8
#  507 Knife's EdgePrivate Sector - Others                       UInt8
#  508 Knife's EdgePrivate Sector - Services                     UInt8
#  509 Knife's EdgePublic Sector - Others                        UInt8
#  510 Knife's EdgeSelf-Employed (Company)                       UInt8
#  511 Knife's EdgeSelf-Employed (Individual)                    UInt8
#  512 LaenteglosPrivate Sector - Services                       UInt8
#  513 LaenteglosPublic Sector - Others                          UInt8
#  514 LaenteglosSelf-Employed (Company)                         UInt8
#  515 LaenteglosSelf-Employed (Individual)                      UInt8
#  516 LaewaesPrivate Sector - Services                          UInt8
#  517 LaewaesPublic Sector - Government                         UInt8
#  518 LaewaesPublic Sector - Others                             UInt8
#  519 LaewaesSelf-Employed (Company)                            UInt8
#  520 LaewaesSelf-Employed (Individual)                         UInt8
#  521 LanercostPrivate Sector - Services                        UInt8
#  522 LanercostPublic Sector - Others                           UInt8
#  523 LanercostSelf-Employed (Individual)                       UInt8
#  524 LewesPrivate Sector - Services                            UInt8
#  525 LewesSelf-Employed (Individual)                           UInt8
#  526 MarnmouthPrivate Sector - Services                        UInt8
#  527 MarnmouthPublic Sector - Others                           UInt8
#  528 MensfieldPrivate Sector - Others                          UInt8
#  529 MensfieldPrivate Sector - Services                        UInt8
#  530 MensfieldPublic Sector - Others                           UInt8
#  531 MensfieldSelf-Employed (Individual)                       UInt8
#  532 MiddlesbroughPrivate Sector - Services                    UInt8
#  533 MiddlesbroughSelf-Employed (Individual)                   UInt8
#  534 MillerVillePrivate Sector - Others                        UInt8
#  535 MillerVillePrivate Sector - Services                      UInt8
#  536 MillerVillePublic Sector - Others                         UInt8
#  537 NorthburyPrivate Sector - Others                          UInt8
#  538 NorthburyPrivate Sector - Services                        UInt8
#  539 NorthburyPublic Sector - Government                       UInt8
#  540 NorthburyPublic Sector - Others                           UInt8
#  541 NorthburySelf-Employed (Company)                          UInt8
#  542 NorthburySelf-Employed (Individual)                       UInt8
#  543 NorthburyUnemployed                                       UInt8
#  544 OrilonPrivate Sector - Services                           UInt8
#  545 OrilonPublic Sector - Others                              UInt8
#  546 OrilonSelf-Employed (Company)                             UInt8
#  547 OrilonSelf-Employed (Individual)                          UInt8
#  548 PranPrivate Sector - Others                               UInt8
#  549 PranPrivate Sector - Services                             UInt8
#  550 PranPublic Sector - Government                            UInt8
#  551 PranPublic Sector - Others                                UInt8
#  552 PranSelf-Employed (Individual)                            UInt8
#  553 Redwick BushPrivate Sector - Services                     UInt8
#  554 Redwick BushSelf-Employed (Company)                       UInt8
#  555 Redwick BushSelf-Employed (Individual)                    UInt8
#  556 SharnwickPrivate Sector - Others                          UInt8
#  557 SharnwickPrivate Sector - Services                        UInt8
#  558 SharnwickPublic Sector - Government                       UInt8
#  559 SharnwickPublic Sector - Others                           UInt8
#  560 SharnwickSelf-Employed (Company)                          UInt8
#  561 SharnwickSelf-Employed (Individual)                       UInt8
#  562 SharptonPrivate Sector - Others                           UInt8
#  563 SharptonPrivate Sector - Services                         UInt8
#  564 SharptonPublic Sector - Government                        UInt8
#  565 SharptonPublic Sector - Others                            UInt8
#  566 SharptonSelf-Employed (Individual)                        UInt8
#  567 TranmerePrivate Sector - Others                           UInt8
#  568 TranmerePrivate Sector - Services                         UInt8
#  569 TranmerePublic Sector - Others                            UInt8
#  570 WatfordPrivate Sector - Others                            UInt8
#  571 WatfordPrivate Sector - Services                          UInt8
#  572 WatfordPublic Sector - Government                         UInt8
#  573 WatfordPublic Sector - Others                             UInt8
#  574 WatfordSelf-Employed (Company)                            UInt8
#  575 WatfordSelf-Employed (Individual)                         UInt8
#  576 WigstonPrivate Sector - Services                          UInt8
#  577 WigstonPublic Sector - Government                         UInt8
#  578 WigstonSelf-Employed (Company)                            UInt8
#  579 WigstonSelf-Employed (Individual)                         UInt8
#  580 WillesdenPrivate Sector - Services                        UInt8
#  581 WoodpinePrivate Sector - Others                           UInt8
#  582 WoodpinePrivate Sector - Services                         UInt8
#  583 Private Sector - OthersAdministratives                    UInt8
#  584 Private Sector - OthersAgriculture and Fishing            UInt8
#  585 Private Sector - OthersCleaners & Handlers                UInt8
#  586 Private Sector - OthersIT                                 UInt8
#  587 Private Sector - OthersMachine Operators & Inspectors     UInt8
#  588 Private Sector - OthersManagement                         UInt8
#  589 Private Sector - OthersOther services                     UInt8
#  590 Private Sector - OthersProfessor                          UInt8
#  591 Private Sector - OthersRepair & constructions             UInt8
#  592 Private Sector - OthersSales                              UInt8
#  593 Private Sector - OthersSecurity                           UInt8
#  594 Private Sector - OthersTransports                         UInt8
#  595 Private Sector - Services Administratives                 UInt8
#  596 Private Sector - Services Agriculture and Fishing         UInt8
#  597 Private Sector - Services Cleaners & Handlers             UInt8
#  598 Private Sector - Services Household Services              UInt8
#  599 Private Sector - Services IT                              UInt8
#  600 Private Sector - Services Machine Operators & Inspectors  UInt8
#  601 Private Sector - Services Management                      UInt8
#  602 Private Sector - Services Other services                  UInt8
#  603 Private Sector - Services Professor                       UInt8
#  604 Private Sector - Services Repair & constructions          UInt8
#  605 Private Sector - Services Sales                           UInt8
#  606 Private Sector - Services Security                        UInt8
#  607 Private Sector - Services Transports                      UInt8
#  608 Public Sector - GovernmentAdministratives                 UInt8
#  609 Public Sector - GovernmentAgriculture and Fishing         UInt8
#  610 Public Sector - GovernmentArmy                            UInt8
#  611 Public Sector - GovernmentCleaners & Handlers             UInt8
#  612 Public Sector - GovernmentIT                              UInt8
#  613 Public Sector - GovernmentMachine Operators & Inspectors  UInt8
#  614 Public Sector - GovernmentManagement                      UInt8
#  615 Public Sector - GovernmentOther services                  UInt8
#  616 Public Sector - GovernmentProfessor                       UInt8
#  617 Public Sector - GovernmentRepair & constructions          UInt8
#  618 Public Sector - GovernmentSales                           UInt8
#  619 Public Sector - GovernmentSecurity                        UInt8
#  620 Public Sector - GovernmentTransports                      UInt8
#  621 Public Sector - OthersAdministratives                     UInt8
#  622 Public Sector - OthersAgriculture and Fishing             UInt8
#  623 Public Sector - OthersCleaners & Handlers                 UInt8
#  624 Public Sector - OthersIT                                  UInt8
#  625 Public Sector - OthersMachine Operators & Inspectors      UInt8
#  626 Public Sector - OthersManagement                          UInt8
#  627 Public Sector - OthersOther services                      UInt8
#  628 Public Sector - OthersProfessor                           UInt8
#  629 Public Sector - OthersRepair & constructions              UInt8
#  630 Public Sector - OthersSales                               UInt8
#  631 Public Sector - OthersSecurity                            UInt8
#  632 Public Sector - OthersTransports                          UInt8
#  633 Self-Employed (Company)Administratives                    UInt8
#  634 Self-Employed (Company)Agriculture and Fishing            UInt8
#  635 Self-Employed (Company)IT                                 UInt8
#  636 Self-Employed (Company)Machine Operators & Inspectors     UInt8
#  637 Self-Employed (Company)Management                         UInt8
#  638 Self-Employed (Company)Other services                     UInt8
#  639 Self-Employed (Company)Professor                          UInt8
#  640 Self-Employed (Company)Repair & constructions             UInt8
#  641 Self-Employed (Company)Sales                              UInt8
#  642 Self-Employed (Company)Security                           UInt8
#  643 Self-Employed (Company)Transports                         UInt8
#  644 Self-Employed (Individual)Administratives                 UInt8
#  645 Self-Employed (Individual)Agriculture and Fishing         UInt8
#  646 Self-Employed (Individual)Cleaners & Handlers             UInt8
#  647 Self-Employed (Individual)IT                              UInt8
#  648 Self-Employed (Individual)Machine Operators & Inspectors  UInt8
#  649 Self-Employed (Individual)Management                      UInt8
#  650 Self-Employed (Individual)Other services                  UInt8
#  651 Self-Employed (Individual)Professor                       UInt8
#  652 Self-Employed (Individual)Repair & constructions          UInt8
#  653 Self-Employed (Individual)Sales                           UInt8
#  654 Self-Employed (Individual)Security                        UInt8
#  655 Self-Employed (Individual)Transports                      UInt8
#  656 UnemployedAdministratives                                 UInt8
#  657 UnemployedAgriculture and Fishing                         UInt8
#  658 UnemployedCleaners & Handlers                             UInt8
#  659 UnemployedOther services                                  UInt8
#  660 UnemployedRepair & constructions                          UInt8
#  661 Income                                                    UInt8
# dtypes: Int32(1), Int64(4), UInt8(647), string(10)
# memory usage: 19.7 MB

# %%
train.phik_matrix().to_excel('phik explore-after.xlsx')
# Out:
# interval columns not set, guessing: ['Age', 'Gender', 'Years of Education', 'Working Hours per week', 'Money Received', 'Ticket Price', 'Money Bi', 'Ticket Bi', 'Africa', 'America', 'Asia', 'Europe', 'Oceania', 'Divorced', 'Married', 'Married - Spouse Missing', 'Married - Spouse in the Army', 'Separated', 'Single', 'Widow', 'Alone', 'Children', 'Husband', 'Other Family', 'Other relatives', 'Wife', 'Aberuthven', 'Aerilon', 'Alverton', 'Aroonshire', 'Auchenshuggle', 'Bellenau', 'Bellmoral', 'Butterpond', 'Carlisle', 'Cherrytown', 'Conriston', 'Drumchapel', 'Eelry', 'Fanfoss', "Fool's March", 'Ironforge', 'Kald', "King's Watch", 'Kirkwall', "Knife's Edge", 'Laenteglos', 'Laewaes', 'Lanercost', 'Lewes', 'Marnmouth', 'Mensfield', 'Middlesbrough', 'MillerVille', 'Northbury', 'Orilon', 'Pran', 'Redwick Bush', 'Sharnwick', 'Sharpton', 'Tranmere', 'Watford', 'Wigston', 'Willesden', 'Woodpine', 'Bachelors', 'Bachelors + PostGraduation', 'High School + PostGraduation', 'High School - 1st Cycle', 'High School - 2nd Cycle', 'High School Complete', 'Masters', 'Masters + PostGraduation', 'Middle School - 1st Cycle', 'Middle School - 2nd Cycle', 'Middle School Complete', 'PhD', 'Preschool', 'Primary School', 'Professional School', 'Professional School + PostGraduation', 'Private Sector - Others', 'Private Sector - Services ', 'Public Sector - Government', 'Public Sector - Others', 'Self-Employed (Company)', 'Self-Employed (Individual)', 'Unemployed', 'Administratives', 'Agriculture and Fishing', 'Army', 'Cleaners & Handlers', 'Household Services', 'IT', 'Machine Operators & Inspectors', 'Management', 'Other services', 'Professor', 'Repair & constructions', 'Sales', 'Security', 'Transports', 'AberuthvenAdministratives', 'AberuthvenCleaners & Handlers', 'AberuthvenIT', 'AberuthvenMachine Operators & Inspectors', 'AberuthvenOther services', 'AberuthvenProfessor', 'AberuthvenRepair & constructions', 'AberuthvenSales', 'AerilonAdministratives', 'AerilonAgriculture and Fishing', 'AerilonCleaners & Handlers', 'AerilonHousehold Services', 'AerilonIT', 'AerilonMachine Operators & Inspectors', 'AerilonManagement', 'AerilonOther services', 'AerilonProfessor', 'AerilonRepair & constructions', 'AerilonSales', 'AerilonTransports', 'AlvertonAdministratives', 'AlvertonAgriculture and Fishing', 'AlvertonCleaners & Handlers', 'AlvertonHousehold Services', 'AlvertonIT', 'AlvertonMachine Operators & Inspectors', 'AlvertonManagement', 'AlvertonOther services', 'AlvertonProfessor', 'AlvertonRepair & constructions', 'AlvertonSales', 'AlvertonSecurity', 'AroonshireAdministratives', 'AroonshireCleaners & Handlers', 'AroonshireHousehold Services', 'AroonshireMachine Operators & Inspectors', 'AroonshireManagement', 'AroonshireOther services', 'AroonshireProfessor', 'AroonshireRepair & constructions', 'AroonshireSales', 'AroonshireTransports', 'AuchenshuggleAdministratives', 'AuchenshuggleAgriculture and Fishing', 'AuchenshuggleCleaners & Handlers', 'AuchenshuggleHousehold Services', 'AuchenshuggleMachine Operators & Inspectors', 'AuchenshuggleManagement', 'AuchenshuggleOther services', 'AuchenshuggleProfessor', 'AuchenshuggleRepair & constructions', 'AuchenshuggleSales', 'AuchenshuggleTransports', 'BellenauMachine Operators & Inspectors', 'BellenauManagement', 'BellenauProfessor', 'BellmoralAdministratives', 'BellmoralCleaners & Handlers', 'BellmoralHousehold Services', 'BellmoralIT', 'BellmoralMachine Operators & Inspectors', 'BellmoralManagement', 'BellmoralOther services', 'BellmoralProfessor', 'BellmoralRepair & constructions', 'BellmoralSales', 'BellmoralTransports', 'ButterpondAdministratives', 'ButterpondCleaners & Handlers', 'ButterpondIT', 'ButterpondMachine Operators & Inspectors', 'ButterpondManagement', 'ButterpondOther services', 'ButterpondProfessor', 'ButterpondRepair & constructions', 'ButterpondSales', 'ButterpondSecurity', 'ButterpondTransports', 'CarlisleAdministratives', 'CarlisleIT', 'CarlisleMachine Operators & Inspectors', 'CarlisleManagement', ' ...
# C:\Users\gogog\anaconda3\lib\site-packages\phik\data_quality.py:55: UserWarning: The number of unique values of variable Base Emp is very large: 150. Are you sure this is not an interval variable? Analysis for pairs of variables including Base Emp might be slow.
#   warnings.warn(
# C:\Users\gogog\anaconda3\lib\site-packages\phik\data_quality.py:55: UserWarning: The number of unique values of variable Base Role is very large: 321. Are you sure this is not an interval variable? Analysis for pairs of variables including Base Role might be slow.
#   warnings.warn(

# %%
train = train.drop(['Native Continent', 'Marital Status','Lives with','Base Area','Education Level','Employment Sector','Role','Base Role','Base Emp','Emp Role'], axis = 1)

# %%
pearsoncorr = train.corr(method='pearson')
pearsoncorr.to_excel('pearson explore.xlsx')

# %%
#train_profile=ProfileReport(train, title='Training Dataset')

# %%
#train_profile.to_notebook_iframe()

# %%
#train_profile.to_file(output_file="Pandas Profiling Report — ML Correl .html")

# %%
train = train_base.copy()

# %%
train.nunique()
# Out:
# Age                                            71
# Gender                                          2
# Years of Education                             14
# Working Hours per week                         90
# Money Bi                                        2
# Ticket Bi                                       2
# Marital Status_Married                          2
# Marital Status_Married - Spouse Missing         2
# Marital Status_Married - Spouse in the Army     2
# Marital Status_Separated                        2
# Marital Status_Single                           2
# Marital Status_Widow                            2
# Lives with_Children                             2
# Lives with_Husband                              2
# Lives with_Other Family                         2
# Lives with_Other relatives                      2
# Lives with_Wife                                 2
# Income                                          2
# dtype: int64

# %%
train = pd.get_dummies(train, columns=['Marital Status', 'Lives with'],drop_first=True)

# %%
train = train.drop(['Native Continent','Base Area','Education Level','Employment Sector','Role','Base Role','Base Emp','Emp Role','Money Received','Ticket Price'], axis = 1)

# %%
train['Income2'] = train['Income'].astype(np.uint8)
train = train.drop(['Income'], axis = 1)
train.rename(columns={'Income2':'Income'}, inplace=True)

# %%
train.columns
# Out:
# Index(['Age', 'Gender', 'Years of Education', 'Working Hours per week',
#        'Money Bi', 'Ticket Bi', 'Marital Status_Married',
#        'Marital Status_Married - Spouse Missing',
#        'Marital Status_Married - Spouse in the Army',
#        'Marital Status_Separated', 'Marital Status_Single',
#        'Marital Status_Widow', 'Lives with_Children', 'Lives with_Husband',
#        'Lives with_Other Family', 'Lives with_Other relatives',
#        'Lives with_Wife', 'Income'],
#       dtype='object')

# %%
# !pip install tensorflow
# !pip install keras
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.3.1-cp38-cp38-win_amd64.whl (342.5 MB)
# Collecting absl-py>=0.7.0
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\gogog\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\gogog\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Collecting astunparse==1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\gogog\anaconda3\lib\site-packages (from tensorflow) (1.18.5)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\gogog\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting keras-preprocessing<1.2,>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorboard<3,>=2.3.0
#   Downloading tensorboard-2.4.0-py3-none-any.whl (10.6 MB)
# Requirement already satisfied: wheel>=0.26 in c:\users\gogog\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.33.2-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# Collecting google-pasta>=0.1.8
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.14.0-py2.py3-none-any.whl (173 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\gogog\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (49.2.0.post20200714)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.23.0-py2.py3-none-any.whl (114 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\gogog\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gogog\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.24.0)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.1.1-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.5"
#   Downloading rsa-4.6-py3-none-any.whl (47 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gogog\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gogog\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gogog\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gogog\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.25.9)
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=f4659cd827b742486f2a0608c48837095938145098b48eeccc94f89e1354c77e
#   Stored in directory: c:\users\gogog\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# Installing collected packages: absl-py, astunparse, termcolor, opt-einsum, keras-preprocessing, cachetools, pyasn1, rsa, pyasn1-modules, google-auth, markdown, protobuf, tensorboard-plugin-wit, grpcio, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard, gast, tensorflow-estimator, google-pasta, tensorflow
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 cachetools-4.1.1 gast-0.3.3 google-auth-1.23.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.33.2 keras-preprocessing-1.1.2 markdown-3.3.3 oauthlib-3.1.0 opt-einsum-3.3.0 protobuf-3.14.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.6 tensorboard-2.4.0 tensorboard-plugin-wit-1.7.0 tensorflow-2.3.1 tensorflow-estimator-2.3.0 termcolor-1.1.0
# Requirement already satisfied: keras in c:\users\gogog\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: scipy>=0.14 in c:\users\gogog\anaconda3\lib\site-packages (from keras) (1.5.0)
# Requirement already satisfied: pyyaml in c:\users\gogog\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\gogog\anaconda3\lib\site-packages (from keras) (1.18.5)
# Requirement already satisfied: h5py in c:\users\gogog\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: six in c:\users\gogog\anaconda3\lib\site-packages (from h5py->keras) (1.15.0)

# %%
conda update --all
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\gogog\anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py38_0           6 KB
#     anaconda-custom            |           py38_1          36 KB
#     anaconda-navigator-1.10.0  |           py38_0         4.9 MB
#     asn1crypto-1.4.0           |             py_0          80 KB
#     astropy-4.0.2              |   py38he774522_0         5.9 MB
#
#     async_generator-1.10       |             py_0          24 KB
#     attrs-20.3.0               |     pyhd3eb1b0_0          43 KB
#     autopep8-1.5.4             |             py_0          42 KB
#     babel-2.8.1                |     pyhd3eb1b0_0         5.3 MB
#     backports-1.0              |     pyhd3eb1b0_2         210 KB
#     backports.functools_lru_cache-1.6.1|     pyhd3eb1b0_0          12 KB
#     bcrypt-3.2.0               |   py38he774522_0          44 KB
#     beautifulsoup4-4.9.3       |     pyhb0f4dca_0          91 KB
#     bitarray-1.6.1             |   py38h2bbff1b_0         116 KB
#     bleach-3.2.1               |             py_0         112 KB
#     blosc-1.20.1               |       h7bd577a_0         142 KB
#     bokeh-2.2.3                |           py38_0         5.4 MB
#     brotlipy-0.7.0             |py38h2bbff1b_1003         412 KB
#     ca-certificates-2020.10.14 |                0         122 KB
#     certifi-2020.11.8          |   py38haa95532_0         148 KB
#     cffi-1.14.3                |   py38hcd4344a_2         228 KB
#     chardet-3.0.4              |py38haa95532_1003         194 KB
#     cloudpickle-1.6.0          |             py_0          30 KB
#     colorama-0.4.4             |             py_0          18 KB
#     conda-4.9.2                |   py38haa95532_0         2.9 MB
#     conda-build-3.20.5         |           py38_1         549 KB
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\pythonw.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\pythonw.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\spyder-script.py']
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\python.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\python.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\spyder-script.py', '--reset']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\pythonw.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\pythonw.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\spyder-script.py']
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\python.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\python.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\spyder-script.py', '--reset']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\python.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\python.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\python.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\python.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\pythonw.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\pythonw.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\anaconda-navigator-script.py']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\pythonw.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\pythonw.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\anaconda-navigator-script.py']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\pythonw.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\pythonw.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\anaconda-navigator-script.py']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\python.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\python.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\jupyter-notebook-script.py', '"%USERPROFILE%/"']
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\gogog\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\pythonw.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\pythonw.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\spyder-script.py']
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\gogog\anaconda3\python.exe, args are ['C:\\Users\\gogog\\anaconda3\\cwp.py', 'C:\\Users\\gogog\\anaconda3', 'C:\\Users\\gogog\\anaconda3\\python.exe', 'C:\\Users\\gogog\\anaconda3\\Scripts\\spyder-script.py', '--reset']
#     conda-package-handling-1.7.2|   py38h76e460a_0         723 KB
#     cryptography-3.2.1         |   py38hcd4344a_1         541 KB
#     cython-0.29.21             |   py38hd77b12b_0         1.8 MB
#     cytoolz-0.11.0             |   py38he774522_0         289 KB
#     dask-2.30.0                |             py_0           5 KB
#     dask-core-2.30.0           |             py_0         605 KB
#     distributed-2.30.1         |   py38haa95532_0         1.0 MB
#     flake8-3.8.4               |             py_0         128 KB
#     freetype-2.10.4            |       hd328e21_0         466 KB
#     fsspec-0.8.3               |             py_0          72 KB
#     gevent-20.9.0              |   py38he774522_0         1.3 MB
#     greenlet-0.4.17            |   py38he774522_0          23 KB
#     importlib-metadata-2.0.0   |             py_1          35 KB
#     importlib_metadata-2.0.0   |                1          11 KB
#     iniconfig-1.1.1            |             py_0           9 KB
#     intel-openmp-2020.2        |              254         1.6 MB
#     intervaltree-3.1.0         |             py_0          26 KB
#     ipython-7.19.0             |   py38hd4e2768_0         998 KB
#     ipywidgets-7.5.1           |             py_1          98 KB
#     isort-5.6.4                |             py_0          78 KB
#     joblib-0.17.0              |             py_0         206 KB
#     jsonschema-3.2.0           |             py_2          47 KB
#     jupyter_client-6.1.7       |             py_0          77 KB
#     jupyter_console-6.2.0      |             py_0          26 KB
#     jupyter_core-4.7.0         |   py38haa95532_0         118 KB
#     jupyterlab-2.2.6           |             py_0         3.4 MB
#     jupyterlab_pygments-0.1.2  |             py_0           8 KB
#     keyring-21.4.0             |           py38_1          69 KB
#     kiwisolver-1.3.0           |   py38hd77b12b_0          78 KB
#     libxml2-2.9.10             |       hb89e7f3_3         1.5 MB
#     llvmlite-0.34.0            |   py38h1a82afc_4        12.4 MB
#     lxml-4.6.1                 |   py38h1350720_0         978 KB
#     lz4-c-1.9.2                |       hf4a77e7_3         106 KB
#     matplotlib-3.3.2           |                0          25 KB
#     matplotlib-base-3.3.2      |   py38hba9282a_0         5.1 MB
#     mkl-2020.2                 |              256       109.3 MB
#     mkl-service-2.3.0          |   py38h2bbff1b_0          47 KB
#     mkl_fft-1.2.0              |   py38h45dec08_0         122 KB
#     more-itertools-8.6.0       |     pyhd3eb1b0_0          40 KB
#     nbclient-0.5.1             |             py_0          58 KB
#     nbconvert-6.0.7            |           py38_0         500 KB
#     nbformat-5.0.8             |             py_0          88 KB
#     nest-asyncio-1.4.3         |     pyhd3eb1b0_0          11 KB
#     networkx-2.5               |             py_0         1.1 MB
#     notebook-6.1.4             |           py38_0         4.3 MB
#     numba-0.51.2               |   py38hf9181ef_1         3.1 MB
#     numpy-1.19.2               |   py38hadc3359_0          22 KB
#     numpy-base-1.19.2          |   py38ha3acd2a_0         3.8 MB
#     numpydoc-1.1.0             |     pyhd3eb1b0_1          42 KB
#     openpyxl-3.0.5             |             py_0         158 KB
#     openssl-1.1.1h             |       he774522_0         4.8 MB
#     pandas-1.1.3               |   py38ha925a31_0         7.5 MB
#     pandoc-2.11                |       h9490d1a_0        14.4 MB
#     pandocfilters-1.4.3        |   py38haa95532_1          14 KB
#     paramiko-2.7.2             |             py_0         143 KB
#     path-15.0.0                |           py38_0          40 KB
#     path.py-12.5.0             |                0           4 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pillow-8.0.1               |   py38h4fa10fc_0         690 KB
#     pip-20.2.4                 |   py38haa95532_0         1.8 MB
#     pkginfo-1.6.1              |   py38haa95532_0          60 KB
#     prompt-toolkit-3.0.8       |             py_0         248 KB
#     prompt_toolkit-3.0.8       |                0          12 KB
#     psutil-5.7.2               |   py38he774522_0         351 KB
#     ptyprocess-0.6.0           |     pyhd3eb1b0_2          20 KB
#     pycosat-0.6.3              |   py38h2bbff1b_0          75 KB
#     pycurl-7.43.0.6            |   py38h7a1dbc1_0          65 KB
#     pydocstyle-5.1.1           |             py_0          38 KB
#     pygments-2.7.2             |     pyhd3eb1b0_0         674 KB
#     pylint-2.6.0               |           py38_0         462 KB
#     pyopenssl-19.1.0           |     pyhd3eb1b0_1          52 KB
#     pyrsistent-0.17.3          |   py38he774522_0          92 KB
#     pysocks-1.7.1              |   py38haa95532_0          31 KB
#     pytest-6.1.1               |           py38_0         428 KB
#     python-jsonrpc-server-0.4.0|             py_0          12 KB
#     python-language-server-0.35.1|             py_0          48 KB
#     pywavelets-1.1.1           |   py38he774522_2         3.4 MB
#     pyzmq-19.0.2               |   py38ha925a31_1         400 KB
#     qtawesome-1.0.1            |             py_0         757 KB
#     qtconsole-4.7.7            |             py_0          96 KB
#     regex-2020.10.15           |   py38he774522_0         298 KB
#     rope-0.18.0                |             py_0         126 KB
#     scikit-image-0.17.2        |   py38h1e1f486_0         8.9 MB
#     scikit-learn-0.23.2        |   py38h47e9c7a_0         4.7 MB
#     scipy-1.5.2                |   py38h14eb087_0        11.9 MB
#     seaborn-0.11.0             |             py_0         210 KB
#     setuptools-50.3.1          |   py38haa95532_1         730 KB
#     singledispatch-3.4.0.3     |          py_1001          12 KB
#     six-1.15.0                 |   py38haa95532_0          27 KB
#     sphinx-3.2.1               |             py_0         1.1 MB
#     sphinxcontrib-websupport-1.2.4|             py_0          34 KB
#     spyder-4.1.5               |           py38_0         5.7 MB
#     spyder-kernels-1.9.4       |           py38_0          98 KB
#     sqlalchemy-1.3.20          |   py38h2bbff1b_0         1.5 MB
#     statsmodels-0.12.0         |   py38he774522_0         8.2 MB
#     sympy-1.6.2                |   py38haa95532_1         8.7 MB
#     tbb-2020.3                 |       h74a9793_0         156 KB
#     tblib-1.7.0                |             py_0          16 KB
#     terminado-0.9.1            |           py38_0          27 KB
#     tifffile-2020.10.1         |   py38h8c2d366_2         292 KB
#     toolz-0.11.1               |             py_0          48 KB
#     tqdm-4.51.0                |     pyhd3eb1b0_0          66 KB
#     traitlets-5.0.5            |             py_0          83 KB
#     typing_extensions-3.7.4.3  |             py_0          28 KB
#     ujson-4.0.1                |   py38ha925a31_0          46 KB
#     urllib3-1.25.11            |             py_0          99 KB
#     wheel-0.35.1               |     pyhd3eb1b0_0          38 KB
#     win_inet_pton-1.1.0        |   py38haa95532_0          35 KB
#     xlsxwriter-1.3.7           |             py_0         108 KB
#     xlwings-0.20.8             |           py38_0         735 KB
#     zipp-3.4.0                 |     pyhd3eb1b0_0          15 KB
#     zope.event-4.5.0           |           py38_0         210 KB
#     zope.interface-5.1.2       |   py38he774522_0         280 KB
#     zstd-1.4.5                 |       h04227a9_0         456 KB
#     ------------------------------------------------------------
#                                            Total:       274.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2020.07-py38_0
#   argon2-cffi        pkgs/main/win-64::argon2-cffi-20.1.0-py38he774522_1
#   async_generator    pkgs/main/noarch::async_generator-1.10-py_0
#   iniconfig          pkgs/main/noarch::iniconfig-1.1.1-py_0
#   jupyterlab_pygmen~ pkgs/main/noarch::jupyterlab_pygments-0.1.2-py_0
#   nbclient           pkgs/main/noarch::nbclient-0.5.1-py_0
#   nest-asyncio       pkgs/main/noarch::nest-asyncio-1.4.3-pyhd3eb1b0_0
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.6.0-pyhd3eb1b0_2
#   tifffile           pkgs/main/win-64::tifffile-2020.10.1-py38h8c2d366_2
#
# The following packages will be UPDATED:
#
#   anaconda-navigator                          1.9.12-py38_0 --> 1.10.0-py38_0
#   asn1crypto         pkgs/main/win-64::asn1crypto-1.3.0-py~ --> pkgs/main/noarch::asn1crypto-1.4.0-py_0
#   astropy                        4.0.1.post1-py38he774522_1 --> 4.0.2-py38he774522_0
#   attrs                                         19.3.0-py_0 --> 20.3.0-pyhd3eb1b0_0
#   autopep8                                       1.5.3-py_0 --> 1.5.4-py_0
#   babel                                          2.8.0-py_0 --> 2.8.1-pyhd3eb1b0_0
#   bcrypt                               3.1.7-py38he774522_1 --> 3.2.0-py38he774522_0
#   beautifulsoup4     pkgs/main/win-64::beautifulsoup4-4.9.~ --> pkgs/main/noarch::beautifulsoup4-4.9.3-pyhb0f4dca_0
#   bitarray                             1.4.0-py38he774522_0 --> 1.6.1-py38h2bbff1b_0
#   bleach                                         3.1.5-py_0 --> 3.2.1-py_0
#   blosc                                   1.19.0-h7bd577a_0 --> 1.20.1-h7bd577a_0
#   bokeh                                        2.1.1-py38_0 --> 2.2.3-py38_0
#   brotlipy                          0.7.0-py38he774522_1000 --> 0.7.0-py38h2bbff1b_1003
#   ca-certificates                               2020.6.24-0 --> 2020.10.14-0
#   certifi                                  2020.6.20-py38_0 --> 2020.11.8-py38haa95532_0
#   cffi                                1.14.0-py38h7a1dbc1_0 --> 1.14.3-py38hcd4344a_2
#   cloudpickle                                    1.5.0-py_0 --> 1.6.0-py_0
#   colorama                                       0.4.3-py_0 --> 0.4.4-py_0
#   conda                                        4.8.5-py38_0 --> 4.9.2-py38haa95532_0
#   conda-build                                3.18.11-py38_1 --> 3.20.5-py38_1
#   conda-package-han~                   1.6.1-py38h62dcd97_0 --> 1.7.2-py38h76e460a_0
#   cryptography                         2.9.2-py38h7a1dbc1_0 --> 3.2.1-py38hcd4344a_1
#   cytoolz                             0.10.1-py38he774522_0 --> 0.11.0-py38he774522_0
#   dask                                          2.20.0-py_0 --> 2.30.0-py_0
#   dask-core                                     2.20.0-py_0 --> 2.30.0-py_0
#   distributed                                 2.20.0-py38_0 --> 2.30.1-py38haa95532_0
#   flake8                                         3.8.3-py_0 --> 3.8.4-py_0
#   freetype                                2.10.2-hd328e21_0 --> 2.10.4-hd328e21_0
#   fsspec                                         0.7.4-py_0 --> 0.8.3-py_0
#   gevent                              20.6.2-py38he774522_0 --> 20.9.0-py38he774522_0
#   greenlet                            0.4.16-py38he774522_0 --> 0.4.17-py38he774522_0
#   importlib-metadata pkgs/main/win-64::importlib-metadata-~ --> pkgs/main/noarch::importlib-metadata-2.0.0-py_1
#   importlib_metadata                                1.7.0-0 --> 2.0.0-1
#   intel-openmp                                   2020.1-216 --> 2020.2-254
#   intervaltree                                   3.0.2-py_1 --> 3.1.0-py_0
#   ipykernel                            5.3.2-py38h5ca1d4c_0 --> 5.3.4-py38h5ca1d4c_0
#   ipython                             7.16.1-py38h5ca1d4c_0 --> 7.19.0-py38hd4e2768_0
#   ipywidgets                                     7.5.1-py_0 --> 7.5.1-py_1
#   isort               pkgs/main/win-64::isort-4.3.21-py38_0 --> pkgs/main/noarch::isort-5.6.4-py_0
#   joblib                                        0.16.0-py_0 --> 0.17.0-py_0
#   jsonschema         pkgs/main/win-64::jsonschema-3.2.0-py~ --> pkgs/main/noarch::jsonschema-3.2.0-py_2
#   jupyter_client                                 6.1.6-py_0 --> 6.1.7-py_0
#   jupyter_console                                6.1.0-py_0 --> 6.2.0-py_0
#   jupyter_core                                 4.6.3-py38_0 --> 4.7.0-py38haa95532_0
#   jupyterlab                                     2.1.5-py_0 --> 2.2.6-py_0
#   keyring                                     21.2.1-py38_0 --> 21.4.0-py38_1
#   kiwisolver                           1.2.0-py38h74a9793_0 --> 1.3.0-py38hd77b12b_0
#   libxml2                                 2.9.10-h464c3ec_1 --> 2.9.10-hb89e7f3_3
#   llvmlite                            0.33.0-py38ha925a31_0 --> 0.34.0-py38h1a82afc_4
#   lxml                                 4.5.2-py38h1350720_0 --> 4.6.1-py38h1350720_0
#   lz4-c                                    1.9.2-h62dcd97_0 --> 1.9.2-hf4a77e7_3
#   matplotlib                                        3.2.2-0 --> 3.3.2-0
#   matplotlib-base                      3.2.2-py38h64f37c6_0 --> 3.3.2-py38hba9282a_0
#   mkl                                            2020.1-216 --> 2020.2-256
#   mkl_fft                              1.1.0-py38h45dec08_0 --> 1.2.0-py38h45dec08_0
#   more-itertools                                 8.4.0-py_0 --> 8.6.0-pyhd3eb1b0_0
#   nbconvert                                    5.6.1-py38_0 --> 6.0.7-py38_0
#   nbformat                                       5.0.7-py_0 --> 5.0.8-py_0
#   networkx                                         2.4-py_1 --> 2.5-py_0
#   notebook                                     6.0.3-py38_0 --> 6.1.4-py38_0
#   numba                               0.50.1-py38h47e9c7a_0 --> 0.51.2-py38hf9181ef_1
#   numpy                               1.18.5-py38h6530119_0 --> 1.19.2-py38hadc3359_0
#   numpy-base                          1.18.5-py38hc3f5095_0 --> 1.19.2-py38ha3acd2a_0
#   numpydoc                                       1.1.0-py_0 --> 1.1.0-pyhd3eb1b0_1
#   openpyxl                                       3.0.4-py_0 --> 3.0.5-py_0
#   openssl                                 1.1.1g-he774522_0 --> 1.1.1h-he774522_0
#   pandas                               1.0.5-py38h47e9c7a_0 --> 1.1.3-py38ha925a31_0
#   pandoc                                             2.10-0 --> 2.11-h9490d1a_0
#   pandocfilters                                1.4.2-py38_1 --> 1.4.3-py38haa95532_1
#   paramiko                                       2.7.1-py_0 --> 2.7.2-py_0
#   path                                        13.1.0-py38_0 --> 15.0.0-py38_0
#   path.py                                          12.4.0-0 --> 12.5.0-0
#   pexpect            pkgs/main/win-64::pexpect-4.8.0-py38_0 --> pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pillow                               7.2.0-py38hcc1f983_0 --> 8.0.1-py38h4fa10fc_0
#   pip                                         20.1.1-py38_1 --> 20.2.4-py38haa95532_0
#   pkginfo                                    1.5.0.1-py38_0 --> 1.6.1-py38haa95532_0
#   prompt-toolkit                                 3.0.5-py_0 --> 3.0.8-py_0
#   prompt_toolkit                                    3.0.5-0 --> 3.0.8-0
#   psutil                               5.7.0-py38he774522_0 --> 5.7.2-py38he774522_0
#   pycurl                            7.43.0.5-py38h7a1dbc1_0 --> 7.43.0.6-py38h7a1dbc1_0
#   pydocstyle                                     5.0.2-py_0 --> 5.1.1-py_0
#   pygments                                       2.6.1-py_0 --> 2.7.2-pyhd3eb1b0_0
#   pylint                                       2.5.3-py38_0 --> 2.6.0-py38_0
#   pyrsistent                          0.16.0-py38he774522_0 --> 0.17.3-py38he774522_0
#   pytest                                       5.4.3-py38_0 --> 6.1.1-py38_0
#   python                                   3.8.3-he1778fa_2 --> 3.8.5-h5fd99cc_1
#   python-jsonrpc-se~                             0.3.4-py_1 --> 0.4.0-py_0
#   python-language-s~ pkgs/main/win-64::python-language-ser~ --> pkgs/main/noarch::python-language-server-0.35.1-py_0
#   pywavelets                           1.1.1-py38he774522_0 --> 1.1.1-py38he774522_2
#   pyzmq                               19.0.1-py38ha925a31_1 --> 19.0.2-py38ha925a31_1
#   qtawesome                                      0.7.2-py_0 --> 1.0.1-py_0
#   qtconsole                                      4.7.5-py_0 --> 4.7.7-py_0
#   regex                             2020.6.8-py38he774522_0 --> 2020.10.15-py38he774522_0
#   rope                                          0.17.0-py_0 --> 0.18.0-py_0
#   scikit-image                        0.16.2-py38h47e9c7a_0 --> 0.17.2-py38h1e1f486_0
#   scikit-learn                        0.23.1-py38h25d0782_0 --> 0.23.2-py38h47e9c7a_0
#   scipy                                1.5.0-py38h9439919_0 --> 1.5.2-py38h14eb087_0
#   seaborn                                       0.10.1-py_0 --> 0.11.0-py_0
#   setuptools                                  49.2.0-py38_0 --> 50.3.1-py38haa95532_1
#   singledispatch     pkgs/main/win-64::singledispatch-3.4.~ --> pkgs/main/noarch::singledispatch-3.4.0.3-py_1001
#   sphinx                                         3.1.2-py_0 --> 3.2.1-py_0
#   sphinxcontrib-web~                             1.2.3-py_0 --> 1.2.4-py_0
#   spyder                                       4.1.4-py38_0 --> 4.1.5-py38_0
#   spyder-kernels                               1.9.2-py38_0 --> 1.9.4-py38_0
#   sqlalchemy                          1.3.18-py38he774522_0 --> 1.3.20-py38h2bbff1b_0
#   sqlite                                  3.32.3-h2a8f88b_0 --> 3.33.0-h2a8f88b_0
#   statsmodels                         0.11.1-py38he774522_0 --> 0.12.0-py38he774522_0
#   sympy                                        1.6.1-py38_0 --> 1.6.2-py38haa95532_1
#   tbb                                     2020.0-h74a9793_0 --> 2020.3-h74a9793_0
#   tblib                                          1.6.0-py_0 --> 1.7.0-py_0
#   terminado                                    0.8.3-py38_0 --> 0.9.1-py38_0
#   toolz                                         0.10.0-py_0 --> 0.11.1-py_0
#   tqdm                                          4.47.0-py_0 --> 4.51.0-pyhd3eb1b0_0
#   traitlets          pkgs/main/win-64::traitlets-4.3.3-py3~ --> pkgs/main/noarch::traitlets-5.0.5-py_0
#   typing_extensions                            3.7.4.2-py_0 --> 3.7.4.3-py_0
#   ujson                                 1.35-py38he774522_0 --> 4.0.1-py38ha925a31_0
#   urllib3                                       1.25.9-py_0 --> 1.25.11-py_0
#   wheel               pkgs/main/win-64::wheel-0.34.2-py38_0 --> pkgs/main/noarch::wheel-0.35.1-pyhd3eb1b0_0
#   xlsxwriter                                     1.2.9-py_0 --> 1.3.7-py_0
#   xlwings                                     0.19.5-py38_0 --> 0.20.8-py38_0
#   zeromq                                   4.3.2-ha925a31_2 --> 4.3.2-ha925a31_3
#   zipp                                           3.1.0-py_0 --> 3.4.0-pyhd3eb1b0_0
#   zope.event                                     4.4-py38_0 --> 4.5.0-py38_0
#   zope.interface                       4.7.1-py38he774522_0 --> 5.1.2-py38he774522_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   six                     pkgs/main/noarch::six-1.15.0-py_0 --> pkgs/main/win-64::six-1.15.0-py38haa95532_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2020.07-py38_0 --> custom-py38_1
#   backports                                        1.0-py_2 --> 1.0-pyhd3eb1b0_2
#   backports.functoo~                             1.6.1-py_0 --> 1.6.1-pyhd3eb1b0_0
#   chardet                                   3.0.4-py38_1003 --> 3.0.4-py38haa95532_1003
#   cython                             0.29.21-py38ha925a31_0 --> 0.29.21-py38hd77b12b_0
#   mkl-service                          2.3.0-py38hb782905_0 --> 2.3.0-py38h2bbff1b_0
#   pycosat                              0.6.3-py38he774522_0 --> 0.6.3-py38h2bbff1b_0
#   pyopenssl                                     19.1.0-py_1 --> 19.1.0-pyhd3eb1b0_1
#   pysocks                                      1.7.1-py38_0 --> 1.7.1-py38haa95532_0
#   win_inet_pton                                1.1.0-py38_0 --> 1.1.0-py38haa95532_0
#   zstd                                     1.4.5-ha9fde0e_0 --> 1.4.5-h04227a9_0
#
#
#
# Downloading and Extracting Packages
#
# ujson-4.0.1          | 46 KB     |            |   0%
# ujson-4.0.1          | 46 KB     | ########## | 100%
# ujson-4.0.1          | 46 KB     | ########## | 100%
#
# pyrsistent-0.17.3    | 92 KB     |            |   0%
# pyrsistent-0.17.3    | 92 KB     | ########## | 100%
# pyrsistent-0.17.3    | 92 KB     | ########## | 100%
#
# beautifulsoup4-4.9.3 | 91 KB     |            |   0%
# beautifulsoup4-4.9.3 | 91 KB     | ########## | 100%
# beautifulsoup4-4.9.3 | 91 KB     | ########## | 100%
#
# anaconda-custom      | 36 KB     |            |   0%
# anaconda-custom      | 36 KB     | ########## | 100%
# anaconda-custom      | 36 KB     | ########## | 100%
#
# cytoolz-0.11.0       | 289 KB    |            |   0%
# cytoolz-0.11.0       | 289 KB    | ########## | 100%
# cytoolz-0.11.0       | 289 KB    | ########## | 100%
#
# tifffile-2020.10.1   | 292 KB    |            |   0%
# tifffile-2020.10.1   | 292 KB    | ########## | 100%
# tifffile-2020.10.1   | 292 KB    | ########## | 100%
#
# jupyter_core-4.7.0   | 118 KB    |            |   0%
# jupyter_core-4.7.0   | 118 KB    | ########## | 100%
# jupyter_core-4.7.0   | 118 KB    | ########## | 100%
#
# cloudpickle-1.6.0    | 30 KB     |            |   0%
# cloudpickle-1.6.0    | 30 KB     | ########## | 100%
# cloudpickle-1.6.0    | 30 KB     | ########## | 100%
#
# jupyter_client-6.1.7 | 77 KB     |            |   0%
# jupyter_client-6.1.7 | 77 KB     | ########## | 100%
# jupyter_client-6.1.7 | 77 KB     | ########## | 100%
#
# rope-0.18.0          | 126 KB    |            |   0%
# rope-0.18.0          | 126 KB    | ########## | 100%
# rope-0.18.0          | 126 KB    | ########## | 100%
#
# astropy-4.0.2        | 5.9 MB    |            |   0%
# astropy-4.0.2        | 5.9 MB    | #          |  11%
# astropy-4.0.2        | 5.9 MB    | ##6        |  26%
# astropy-4.0.2        | 5.9 MB    | ###9       |  40%
# astropy-4.0.2        | 5.9 MB    | #####      |  50%
# astropy-4.0.2        | 5.9 MB    | ######4    |  64%
# astropy-4.0.2        | 5.9 MB    | #######8   |  79%
# astropy-4.0.2        | 5.9 MB    | #########2 |  93%
# astropy-4.0.2        | 5.9 MB    | ########## | 100%
#
# joblib-0.17.0        | 206 KB    |            |   0%
# joblib-0.17.0        | 206 KB    | ########## | 100%
# joblib-0.17.0        | 206 KB    | ########## | 100%
#
# path-15.0.0          | 40 KB     |            |   0%
# path-15.0.0          | 40 KB     | ########## | 100%
# path-15.0.0          | 40 KB     | ########## | 100%
#
# scikit-learn-0.23.2  | 4.7 MB    |            |   0%
# scikit-learn-0.23.2  | 4.7 MB    | #2         |  12%
# scikit-learn-0.23.2  | 4.7 MB    | ###1       |  32%
# scikit-learn-0.23.2  | 4.7 MB    | ####7      |  48%
# scikit-learn-0.23.2  | 4.7 MB    | ######4    |  65%
# scikit-learn-0.23.2  | 4.7 MB    | ########   |  81%
# scikit-learn-0.23.2  | 4.7 MB    | #########7 |  97%
# scikit-learn-0.23.2  | 4.7 MB    | ########## | 100%
#
# regex-2020.10.15     | 298 KB    |            |   0%
# regex-2020.10.15     | 298 KB    | #####9     |  59%
# regex-2020.10.15     | 298 KB    | ########## | 100%
# regex-2020.10.15     | 298 KB    | ########## | 100%
#
# isort-5.6.4          | 78 KB     |            |   0%
# isort-5.6.4          | 78 KB     | ########## | 100%
# isort-5.6.4          | 78 KB     | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# bitarray-1.6.1       | 116 KB    |            |   0%
# bitarray-1.6.1       | 116 KB    | ########## | 100%
# bitarray-1.6.1       | 116 KB    | ########## | 100%
#
# lxml-4.6.1           | 978 KB    |            |   0%
# lxml-4.6.1           | 978 KB    | ######5    |  65%
# lxml-4.6.1           | 978 KB    | ########## | 100%
# lxml-4.6.1           | 978 KB    | ########## | 100%
#
# tblib-1.7.0          | 16 KB     |            |   0%
# tblib-1.7.0          | 16 KB     | ########## | 100%
# tblib-1.7.0          | 16 KB     | ########## | 100%
#
# typing_extensions-3. | 28 KB     |            |   0%
# typing_extensions-3. | 28 KB     | ########## | 100%
# typing_extensions-3. | 28 KB     | ########## | 100%
#
# pandocfilters-1.4.3  | 14 KB     |            |   0%
# pandocfilters-1.4.3  | 14 KB     | ########## | 100%
# pandocfilters-1.4.3  | 14 KB     | ########## | 100%
#
# pyopenssl-19.1.0     | 52 KB     |            |   0%
# pyopenssl-19.1.0     | 52 KB     | ########## | 100%
# pyopenssl-19.1.0     | 52 KB     | ########## | 100%
#
# asn1crypto-1.4.0     | 80 KB     |            |   0%
# asn1crypto-1.4.0     | 80 KB     | ########## | 100%
# asn1crypto-1.4.0     | 80 KB     | ########## | 100%
#
# backports.functools_ | 12 KB     |            |   0%
# backports.functools_ | 12 KB     | ########## | 100%
# backports.functools_ | 12 KB     | ########## | 100%
#
# async_generator-1.10 | 24 KB     |            |   0%
# async_generator-1.10 | 24 KB     | ########## | 100%
# async_generator-1.10 | 24 KB     | ########## | 100%
#
# freetype-2.10.4      | 466 KB    |            |   0%
# freetype-2.10.4      | 466 KB    | ########## | 100%
# freetype-2.10.4      | 466 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 122 KB    |            |   0%
# mkl_fft-1.2.0        | 122 KB    | ########## | 100%
# mkl_fft-1.2.0        | 122 KB    | ########## | 100%
#
# singledispatch-3.4.0 | 12 KB     |            |   0%
# singledispatch-3.4.0 | 12 KB     | ########## | 100%
#
# cryptography-3.2.1   | 541 KB    |            |   0%
# cryptography-3.2.1   | 541 KB    | ########## | 100%
# cryptography-3.2.1   | 541 KB    | ########## | 100%
#
# keyring-21.4.0       | 69 KB     |            |   0%
# keyring-21.4.0       | 69 KB     | ########## | 100%
# keyring-21.4.0       | 69 KB     | ########## | 100%
#
# more-itertools-8.6.0 | 40 KB     |            |   0%
# more-itertools-8.6.0 | 40 KB     | ########## | 100%
# more-itertools-8.6.0 | 40 KB     | ########## | 100%
#
# cffi-1.14.3          | 228 KB    |            |   0%
# cffi-1.14.3          | 228 KB    | ########## | 100%
# cffi-1.14.3          | 228 KB    | ########## | 100%
#
# pytest-6.1.1         | 428 KB    |            |   0%
# pytest-6.1.1         | 428 KB    | ########## | 100%
# pytest-6.1.1         | 428 KB    | ########## | 100%
#
# anaconda-navigator-1 | 4.9 MB    |            |   0%
# anaconda-navigator-1 | 4.9 MB    | #          |  10%
# anaconda-navigator-1 | 4.9 MB    | ##5        |  25%
# anaconda-navigator-1 | 4.9 MB    | ###8       |  39%
# anaconda-navigator-1 | 4.9 MB    | #####6     |  57%
# anaconda-navigator-1 | 4.9 MB    | ######9    |  70%
# anaconda-navigator-1 | 4.9 MB    | ########1  |  81%
# anaconda-navigator-1 | 4.9 MB    | #########8 |  98%
# anaconda-navigator-1 | 4.9 MB    | ########## | 100%
#
# jupyter_console-6.2. | 26 KB     |            |   0%
# jupyter_console-6.2. | 26 KB     | ########## | 100%
# jupyter_console-6.2. | 26 KB     | ########## | 100%
#
# tbb-2020.3           | 156 KB    |            |   0%
# tbb-2020.3           | 156 KB    | ########## | 100%
# tbb-2020.3           | 156 KB    | ########## | 100%
#
# bokeh-2.2.3          | 5.4 MB    |            |   0%
# bokeh-2.2.3          | 5.4 MB    | 8          |   9%
# bokeh-2.2.3          | 5.4 MB    | ##4        |  25%
# bokeh-2.2.3          | 5.4 MB    | ####4      |  44%
# bokeh-2.2.3          | 5.4 MB    | #####8     |  59%
# bokeh-2.2.3          | 5.4 MB    | #######3   |  73%
# bokeh-2.2.3          | 5.4 MB    | ########9  |  89%
# bokeh-2.2.3          | 5.4 MB    | ########## | 100%
#
# seaborn-0.11.0       | 210 KB    |            |   0%
# seaborn-0.11.0       | 210 KB    | ########## | 100%
# seaborn-0.11.0       | 210 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 3.8 MB    |            |   0%
# numpy-base-1.19.2    | 3.8 MB    | #1         |  12%
# numpy-base-1.19.2    | 3.8 MB    | ###6       |  37%
# numpy-base-1.19.2    | 3.8 MB    | #####4     |  55%
# numpy-base-1.19.2    | 3.8 MB    | #######6   |  77%
# numpy-base-1.19.2    | 3.8 MB    | #########8 |  99%
# numpy-base-1.19.2    | 3.8 MB    | ########## | 100%
#
# wheel-0.35.1         | 38 KB     |            |   0%
# wheel-0.35.1         | 38 KB     | ########## | 100%
# wheel-0.35.1         | 38 KB     | ########## | 100%
#
# pycurl-7.43.0.6      | 65 KB     |            |   0%
# pycurl-7.43.0.6      | 65 KB     | ########## | 100%
# pycurl-7.43.0.6      | 65 KB     | ########## | 100%
#
# pip-20.2.4           | 1.8 MB    |            |   0%
# pip-20.2.4           | 1.8 MB    | ##3        |  24%
# pip-20.2.4           | 1.8 MB    | #####4     |  54%
# pip-20.2.4           | 1.8 MB    | ########8  |  89%
# pip-20.2.4           | 1.8 MB    | ########## | 100%
#
# openpyxl-3.0.5       | 158 KB    |            |   0%
# openpyxl-3.0.5       | 158 KB    | ########## | 100%
# openpyxl-3.0.5       | 158 KB    | ########## | 100%
#
# jsonschema-3.2.0     | 47 KB     |            |   0%
# jsonschema-3.2.0     | 47 KB     | ########## | 100%
# jsonschema-3.2.0     | 47 KB     | ########## | 100%
#
# qtconsole-4.7.7      | 96 KB     |            |   0%
# qtconsole-4.7.7      | 96 KB     | ########## | 100%
# qtconsole-4.7.7      | 96 KB     | ########## | 100%
#
# mkl-2020.2           | 109.3 MB  |            |   0%
# mkl-2020.2           | 109.3 MB  |            |   0%
# mkl-2020.2           | 109.3 MB  | 1          |   1%
# mkl-2020.2           | 109.3 MB  | 1          |   2%
# mkl-2020.2           | 109.3 MB  | 2          |   3%
# mkl-2020.2           | 109.3 MB  | 3          |   3%
# mkl-2020.2           | 109.3 MB  | 4          |   4%
# mkl-2020.2           | 109.3 MB  | 4          |   5%
# mkl-2020.2           | 109.3 MB  | 5          |   5%
# mkl-2020.2           | 109.3 MB  | 6          |   6%
# mkl-2020.2           | 109.3 MB  | 7          |   7%
# mkl-2020.2           | 109.3 MB  | 7          |   8%
# mkl-2020.2           | 109.3 MB  | 8          |   8%
# mkl-2020.2           | 109.3 MB  | 9          |   9%
# mkl-2020.2           | 109.3 MB  | 9          |  10%
# mkl-2020.2           | 109.3 MB  | #          |  11%
# mkl-2020.2           | 109.3 MB  | #1         |  12%
# mkl-2020.2           | 109.3 MB  | #2         |  12%
# mkl-2020.2           | 109.3 MB  | #3         |  13%
# mkl-2020.2           | 109.3 MB  | #4         |  14%
# mkl-2020.2           | 109.3 MB  | #4         |  15%
# mkl-2020.2           | 109.3 MB  | #5         |  16%
# mkl-2020.2           | 109.3 MB  | #6         |  16%
# mkl-2020.2           | 109.3 MB  | #6         |  17%
# mkl-2020.2           | 109.3 MB  | #7         |  17%
# mkl-2020.2           | 109.3 MB  | #7         |  18%
# mkl-2020.2           | 109.3 MB  | #8         |  18%
# mkl-2020.2           | 109.3 MB  | #8         |  19%
# mkl-2020.2           | 109.3 MB  | #9         |  20%
# mkl-2020.2           | 109.3 MB  | ##         |  20%
# mkl-2020.2           | 109.3 MB  | ##         |  21%
# mkl-2020.2           | 109.3 MB  | ##1        |  21%
# mkl-2020.2           | 109.3 MB  | ##1        |  22%
# mkl-2020.2           | 109.3 MB  | ##2        |  22%
# mkl-2020.2           | 109.3 MB  | ##3        |  23%
# mkl-2020.2           | 109.3 MB  | ##3        |  24%
# mkl-2020.2           | 109.3 MB  | ##4        |  24%
# mkl-2020.2           | 109.3 MB  | ##5        |  25%
# mkl-2020.2           | 109.3 MB  | ##5        |  26%
# mkl-2020.2           | 109.3 MB  | ##6        |  26%
# mkl-2020.2           | 109.3 MB  | ##7        |  27%
# mkl-2020.2           | 109.3 MB  | ##7        |  28%
# mkl-2020.2           | 109.3 MB  | ##8        |  28%
# mkl-2020.2           | 109.3 MB  | ##9        |  29%
# mkl-2020.2           | 109.3 MB  | ##9        |  30%
# mkl-2020.2           | 109.3 MB  | ###        |  31%
# mkl-2020.2           | 109.3 MB  | ###1       |  31%
# mkl-2020.2           | 109.3 MB  | ###1       |  32%
# mkl-2020.2           | 109.3 MB  | ###2       |  33%
# mkl-2020.2           | 109.3 MB  | ###3       |  33%
# mkl-2020.2           | 109.3 MB  | ###4       |  34%
# mkl-2020.2           | 109.3 MB  | ###4       |  35%
# mkl-2020.2           | 109.3 MB  | ###5       |  35%
# mkl-2020.2           | 109.3 MB  | ###6       |  36%
# mkl-2020.2           | 109.3 MB  | ###6       |  37%
# mkl-2020.2           | 109.3 MB  | ###7       |  38%
# mkl-2020.2           | 109.3 MB  | ###8       |  38%
# mkl-2020.2           | 109.3 MB  | ###8       |  39%
# mkl-2020.2           | 109.3 MB  | ###9       |  40%
# mkl-2020.2           | 109.3 MB  | ####       |  40%
# mkl-2020.2           | 109.3 MB  | ####       |  41%
# mkl-2020.2           | 109.3 MB  | ####1      |  42%
# mkl-2020.2           | 109.3 MB  | ####2      |  42%
# mkl-2020.2           | 109.3 MB  | ####3      |  43%
# mkl-2020.2           | 109.3 MB  | ####4      |  44%
# mkl-2020.2           | 109.3 MB  | ####4      |  45%
# mkl-2020.2           | 109.3 MB  | ####5      |  46%
# mkl-2020.2           | 109.3 MB  | ####6      |  47%
# mkl-2020.2           | 109.3 MB  | ####7      |  47%
# mkl-2020.2           | 109.3 MB  | ####8      |  48%
# mkl-2020.2           | 109.3 MB  | ####8      |  49%
# mkl-2020.2           | 109.3 MB  | ####9      |  50%
# mkl-2020.2           | 109.3 MB  | #####      |  50%
# mkl-2020.2           | 109.3 MB  | #####1     |  51%
# mkl-2020.2           | 109.3 MB  | #####1     |  52%
# mkl-2020.2           | 109.3 MB  | #####2     |  53%
# mkl-2020.2           | 109.3 MB  | #####3     |  53%
# mkl-2020.2           | 109.3 MB  | #####4     |  54%
# mkl-2020.2           | 109.3 MB  | #####4     |  55%
# mkl-2020.2           | 109.3 MB  | #####5     |  56%
# mkl-2020.2           | 109.3 MB  | #####6     |  56%
# mkl-2020.2           | 109.3 MB  | #####7     |  57%
# mkl-2020.2           | 109.3 MB  | #####7     |  58%
# mkl-2020.2           | 109.3 MB  | #####8     |  59%
# mkl-2020.2           | 109.3 MB  | #####9     |  59%
# mkl-2020.2           | 109.3 MB  | #####9     |  60%
# mkl-2020.2           | 109.3 MB  | ######     |  60%
# mkl-2020.2           | 109.3 MB  | ######1    |  61%
# mkl-2020.2           | 109.3 MB  | ######1    |  62%
# mkl-2020.2           | 109.3 MB  | ######2    |  62%
# mkl-2020.2           | 109.3 MB  | ######3    |  63%
# mkl-2020.2           | 109.3 MB  | ######3    |  64%
# mkl-2020.2           | 109.3 MB  | ######4    |  64%
# mkl-2020.2           | 109.3 MB  | ######5    |  65%
# mkl-2020.2           | 109.3 MB  | ######5    |  66%
# mkl-2020.2           | 109.3 MB  | ######6    |  66%
# mkl-2020.2           | 109.3 MB  | ######7    |  67%
# mkl-2020.2           | 109.3 MB  | ######7    |  68%
# mkl-2020.2           | 109.3 MB  | ######8    |  69%
# mkl-2020.2           | 109.3 MB  | ######9    |  69%
# mkl-2020.2           | 109.3 MB  | ######9    |  70%
# mkl-2020.2           | 109.3 MB  | #######    |  71%
# mkl-2020.2           | 109.3 MB  | #######1   |  71%
# mkl-2020.2           | 109.3 MB  | #######2   |  72%
# mkl-2020.2           | 109.3 MB  | #######2   |  73%
# mkl-2020.2           | 109.3 MB  | #######3   |  74%
# mkl-2020.2           | 109.3 MB  | #######4   |  74%
# mkl-2020.2           | 109.3 MB  | #######5   |  75%
# mkl-2020.2           | 109.3 MB  | #######5   |  76%
# mkl-2020.2           | 109.3 MB  | #######6   |  77%
# mkl-2020.2           | 109.3 MB  | #######7   |  78%
# mkl-2020.2           | 109.3 MB  | #######8   |  78%
# mkl-2020.2           | 109.3 MB  | #######9   |  79%
# mkl-2020.2           | 109.3 MB  | #######9   |  80%
# mkl-2020.2           | 109.3 MB  | ########   |  81%
# mkl-2020.2           | 109.3 MB  | ########1  |  82%
# mkl-2020.2           | 109.3 MB  | ########2  |  82%
# mkl-2020.2           | 109.3 MB  | ########3  |  83%
# mkl-2020.2           | 109.3 MB  | ########4  |  84%
# mkl-2020.2           | 109.3 MB  | ########5  |  85%
# mkl-2020.2           | 109.3 MB  | ########5  |  86%
# mkl-2020.2           | 109.3 MB  | ########6  |  87%
# mkl-2020.2           | 109.3 MB  | ########7  |  88%
# mkl-2020.2           | 109.3 MB  | ########8  |  88%
# mkl-2020.2           | 109.3 MB  | ########9  |  89%
# mkl-2020.2           | 109.3 MB  | #########  |  90%
# mkl-2020.2           | 109.3 MB  | #########  |  91%
# mkl-2020.2           | 109.3 MB  | #########1 |  92%
# mkl-2020.2           | 109.3 MB  | #########2 |  92%
# mkl-2020.2           | 109.3 MB  | #########3 |  93%
# mkl-2020.2           | 109.3 MB  | #########3 |  94%
# mkl-2020.2           | 109.3 MB  | #########4 |  95%
# mkl-2020.2           | 109.3 MB  | #########5 |  95%
# mkl-2020.2           | 109.3 MB  | #########6 |  96%
# mkl-2020.2           | 109.3 MB  | #########6 |  97%
# mkl-2020.2           | 109.3 MB  | #########7 |  97%
# mkl-2020.2           | 109.3 MB  | #########8 |  98%
# mkl-2020.2           | 109.3 MB  | #########8 |  99%
# mkl-2020.2           | 109.3 MB  | #########9 |  99%
# mkl-2020.2           | 109.3 MB  | ########## | 100%
# mkl-2020.2           | 109.3 MB  | ########## | 100%
#
# zstd-1.4.5           | 456 KB    |            |   0%
# zstd-1.4.5           | 456 KB    | #########1 |  91%
# zstd-1.4.5           | 456 KB    | ########## | 100%
#
# spyder-kernels-1.9.4 | 98 KB     |            |   0%
# spyder-kernels-1.9.4 | 98 KB     | ########## | 100%
# spyder-kernels-1.9.4 | 98 KB     | ########## | 100%
#
# python-jsonrpc-serve | 12 KB     |            |   0%
# python-jsonrpc-serve | 12 KB     | ########## | 100%
# python-jsonrpc-serve | 12 KB     | ########## | 100%
#
# pycosat-0.6.3        | 75 KB     |            |   0%
# pycosat-0.6.3        | 75 KB     | ########## | 100%
# pycosat-0.6.3        | 75 KB     | ########## | 100%
#
# xlwings-0.20.8       | 735 KB    |            |   0%
# xlwings-0.20.8       | 735 KB    | #######1   |  72%
# xlwings-0.20.8       | 735 KB    | ########## | 100%
# xlwings-0.20.8       | 735 KB    | ########## | 100%
#
# six-1.15.0           | 27 KB     |            |   0%
# six-1.15.0           | 27 KB     | ########## | 100%
# six-1.15.0           | 27 KB     | ########## | 100%
#
# spyder-4.1.5         | 5.7 MB    |            |   0%
# spyder-4.1.5         | 5.7 MB    | #          |  10%
# spyder-4.1.5         | 5.7 MB    | ##6        |  26%
# spyder-4.1.5         | 5.7 MB    | ####2      |  42%
# spyder-4.1.5         | 5.7 MB    | #####8     |  58%
# spyder-4.1.5         | 5.7 MB    | #######2   |  73%
# spyder-4.1.5         | 5.7 MB    | ########5  |  85%
# spyder-4.1.5         | 5.7 MB    | ########## | 100%
# spyder-4.1.5         | 5.7 MB    | ########## | 100%
#
# importlib-metadata-2 | 35 KB     |            |   0%
# importlib-metadata-2 | 35 KB     | ########## | 100%
# importlib-metadata-2 | 35 KB     | ########## | 100%
#
# flake8-3.8.4         | 128 KB    |            |   0%
# flake8-3.8.4         | 128 KB    | ########## | 100%
# flake8-3.8.4         | 128 KB    | ########## | 100%
#
# sqlalchemy-1.3.20    | 1.5 MB    |            |   0%
# sqlalchemy-1.3.20    | 1.5 MB    | ##7        |  28%
# sqlalchemy-1.3.20    | 1.5 MB    | ######3    |  64%
# sqlalchemy-1.3.20    | 1.5 MB    | #########7 |  97%
# sqlalchemy-1.3.20    | 1.5 MB    | ########## | 100%
#
# greenlet-0.4.17      | 23 KB     |            |   0%
# greenlet-0.4.17      | 23 KB     | ########## | 100%
# greenlet-0.4.17      | 23 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 47 KB     |            |   0%
# mkl-service-2.3.0    | 47 KB     | ########## | 100%
# mkl-service-2.3.0    | 47 KB     | ########## | 100%
#
# tqdm-4.51.0          | 66 KB     |            |   0%
# tqdm-4.51.0          | 66 KB     | ########## | 100%
# tqdm-4.51.0          | 66 KB     | ########## | 100%
#
# bcrypt-3.2.0         | 44 KB     |            |   0%
# bcrypt-3.2.0         | 44 KB     | ########## | 100%
# bcrypt-3.2.0         | 44 KB     | ########## | 100%
#
# networkx-2.5         | 1.1 MB    |            |   0%
# networkx-2.5         | 1.1 MB    | ####8      |  48%
# networkx-2.5         | 1.1 MB    | ########## | 100%
# networkx-2.5         | 1.1 MB    | ########## | 100%
#
# ptyprocess-0.6.0     | 20 KB     |            |   0%
# ptyprocess-0.6.0     | 20 KB     | ########## | 100%
# ptyprocess-0.6.0     | 20 KB     | ########## | 100%
#
# backports-1.0        | 210 KB    |            |   0%
# backports-1.0        | 210 KB    | ########## | 100%
# backports-1.0        | 210 KB    | ########## | 100%
#
# python-language-serv | 48 KB     |            |   0%
# python-language-serv | 48 KB     | ########## | 100%
# python-language-serv | 48 KB     | ########## | 100%
#
# statsmodels-0.12.0   | 8.2 MB    |            |   0%
# statsmodels-0.12.0   | 8.2 MB    | 3          |   3%
# statsmodels-0.12.0   | 8.2 MB    | #2         |  13%
# statsmodels-0.12.0   | 8.2 MB    | ##1        |  21%
# statsmodels-0.12.0   | 8.2 MB    | ###        |  31%
# statsmodels-0.12.0   | 8.2 MB    | ###9       |  39%
# statsmodels-0.12.0   | 8.2 MB    | #####      |  50%
# statsmodels-0.12.0   | 8.2 MB    | #####9     |  59%
# statsmodels-0.12.0   | 8.2 MB    | #######    |  70%
# statsmodels-0.12.0   | 8.2 MB    | #######9   |  80%
# statsmodels-0.12.0   | 8.2 MB    | ########9  |  90%
# statsmodels-0.12.0   | 8.2 MB    | ########## | 100%
# statsmodels-0.12.0   | 8.2 MB    | ########## | 100%
#
# dask-core-2.30.0     | 605 KB    |            |   0%
# dask-core-2.30.0     | 605 KB    | ########## | 100%
# dask-core-2.30.0     | 605 KB    | ########## | 100%
#
# pillow-8.0.1         | 690 KB    |            |   0%
# pillow-8.0.1         | 690 KB    | #########5 |  95%
# pillow-8.0.1         | 690 KB    | ########## | 100%
#
# babel-2.8.1          | 5.3 MB    |            |   0%
# babel-2.8.1          | 5.3 MB    | #1         |  12%
# ...
# prompt-toolkit-3.0.8 | 248 KB    | ########## | 100%
#
# jupyterlab_pygments- | 8 KB      |            |   0%
# jupyterlab_pygments- | 8 KB      | ########## | 100%
# jupyterlab_pygments- | 8 KB      | ########## | 100%
#
# openssl-1.1.1h       | 4.8 MB    |            |   0%
# openssl-1.1.1h       | 4.8 MB    | 7          |   8%
# openssl-1.1.1h       | 4.8 MB    | ##5        |  25%
# openssl-1.1.1h       | 4.8 MB    | ###8       |  38%
# openssl-1.1.1h       | 4.8 MB    | #####2     |  52%
# openssl-1.1.1h       | 4.8 MB    | ######9    |  69%
# openssl-1.1.1h       | 4.8 MB    | ########8  |  88%
# openssl-1.1.1h       | 4.8 MB    | ########## | 100%
#
# nbconvert-6.0.7      | 500 KB    |            |   0%
# nbconvert-6.0.7      | 500 KB    | ########## | 100%
# nbconvert-6.0.7      | 500 KB    | ########## | 100%
#
# nbformat-5.0.8       | 88 KB     |            |   0%
# nbformat-5.0.8       | 88 KB     | ########## | 100%
# nbformat-5.0.8       | 88 KB     | ########## | 100%
#
# llvmlite-0.34.0      | 12.4 MB   |            |   0%
# llvmlite-0.34.0      | 12.4 MB   | 4          |   5%
# llvmlite-0.34.0      | 12.4 MB   | #1         |  12%
# llvmlite-0.34.0      | 12.4 MB   | #9         |  19%
# llvmlite-0.34.0      | 12.4 MB   | ##5        |  26%
# llvmlite-0.34.0      | 12.4 MB   | ###2       |  32%
# llvmlite-0.34.0      | 12.4 MB   | ###9       |  40%
# llvmlite-0.34.0      | 12.4 MB   | ####6      |  46%
# llvmlite-0.34.0      | 12.4 MB   | #####2     |  53%
# llvmlite-0.34.0      | 12.4 MB   | ######     |  60%
# llvmlite-0.34.0      | 12.4 MB   | ######6    |  67%
# llvmlite-0.34.0      | 12.4 MB   | #######2   |  73%
# llvmlite-0.34.0      | 12.4 MB   | #######9   |  79%
# llvmlite-0.34.0      | 12.4 MB   | ########5  |  86%
# llvmlite-0.34.0      | 12.4 MB   | #########1 |  92%
# llvmlite-0.34.0      | 12.4 MB   | #########7 |  98%
# llvmlite-0.34.0      | 12.4 MB   | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | 9          |  10%
# matplotlib-base-3.3. | 5.1 MB    | ##6        |  26%
# matplotlib-base-3.3. | 5.1 MB    | ####2      |  43%
# matplotlib-base-3.3. | 5.1 MB    | #####6     |  57%
# matplotlib-base-3.3. | 5.1 MB    | #######3   |  73%
# matplotlib-base-3.3. | 5.1 MB    | ########6  |  87%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# urllib3-1.25.11      | 99 KB     |            |   0%
# urllib3-1.25.11      | 99 KB     | ########## | 100%
# urllib3-1.25.11      | 99 KB     | ########## | 100%
# pandas-1.1.3         | 7.5 MB    |            |   0%
# pandas-1.1.3         | 7.5 MB    | 6          |   7%
# pandas-1.1.3         | 7.5 MB    | #6         |  16%
# pandas-1.1.3         | 7.5 MB    | ##4        |  25%
# pandas-1.1.3         | 7.5 MB    | ###4       |  34%
# pandas-1.1.3         | 7.5 MB    | ####4      |  45%
# pandas-1.1.3         | 7.5 MB    | #####3     |  54%
# pandas-1.1.3         | 7.5 MB    | ######5    |  65%
# pandas-1.1.3         | 7.5 MB    | #######5   |  75%
# pandas-1.1.3         | 7.5 MB    | ########4  |  84%
# pandas-1.1.3         | 7.5 MB    | #########9 |  99%
# pandas-1.1.3         | 7.5 MB    | ########## | 100%
#
# bleach-3.2.1         | 112 KB    |            |   0%
# bleach-3.2.1         | 112 KB    | ########## | 100%
# bleach-3.2.1         | 112 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 1.6 MB    |            |   0%
# intel-openmp-2020.2  | 1.6 MB    | ###5       |  36%
# intel-openmp-2020.2  | 1.6 MB    | ########8  |  88%
# intel-openmp-2020.2  | 1.6 MB    | ########## | 100%
#
# libxml2-2.9.10       | 1.5 MB    |            |   0%
# libxml2-2.9.10       | 1.5 MB    | #3         |  14%
# libxml2-2.9.10       | 1.5 MB    | ##2        |  22%
# libxml2-2.9.10       | 1.5 MB    | ####6      |  46%
# libxml2-2.9.10       | 1.5 MB    | #####7     |  58%
# libxml2-2.9.10       | 1.5 MB    | ########## | 100%
# libxml2-2.9.10       | 1.5 MB    | ########## | 100%
#
# nest-asyncio-1.4.3   | 11 KB     |            |   0%
# nest-asyncio-1.4.3   | 11 KB     | ########## | 100%
# nest-asyncio-1.4.3   | 11 KB     | ########## | 100%
#
# intervaltree-3.1.0   | 26 KB     |            |   0%
# intervaltree-3.1.0   | 26 KB     | ########## | 100%
# intervaltree-3.1.0   | 26 KB     | ########## | 100%
#
# zope.interface-5.1.2 | 280 KB    |            |   0%
# zope.interface-5.1.2 | 280 KB    | ########## | 100%
# zope.interface-5.1.2 | 280 KB    | ########## | 100%
#
# pywavelets-1.1.1     | 3.4 MB    |            |   0%
# pywavelets-1.1.1     | 3.4 MB    | #1         |  11%
# pywavelets-1.1.1     | 3.4 MB    | ##6        |  26%
# pywavelets-1.1.1     | 3.4 MB    | ####3      |  43%
# pywavelets-1.1.1     | 3.4 MB    | ######1    |  61%
# pywavelets-1.1.1     | 3.4 MB    | ########5  |  86%
# pywavelets-1.1.1     | 3.4 MB    | ########## | 100%
#
# path.py-12.5.0       | 4 KB      |            |   0%
# path.py-12.5.0       | 4 KB      | ########## | 100%
#
# gevent-20.9.0        | 1.3 MB    |            |   0%
# gevent-20.9.0        | 1.3 MB    | ####8      |  49%
# gevent-20.9.0        | 1.3 MB    | ########## | 100%
# gevent-20.9.0        | 1.3 MB    | ########## | 100%
#
# conda-build-3.20.5   | 549 KB    |            |   0%
# conda-build-3.20.5   | 549 KB    | #########6 |  96%
# conda-build-3.20.5   | 549 KB    | ########## | 100%
#
# fsspec-0.8.3         | 72 KB     |            |   0%
# fsspec-0.8.3         | 72 KB     | ########## | 100%
# fsspec-0.8.3         | 72 KB     | ########## | 100%
#
# importlib_metadata-2 | 11 KB     |            |   0%
# importlib_metadata-2 | 11 KB     | ########## | 100%
# importlib_metadata-2 | 11 KB     | ########## | 100%
#
# dask-2.30.0          | 5 KB      |            |   0%
# dask-2.30.0          | 5 KB      | ########## | 100%
# dask-2.30.0          | 5 KB      | ########## | 100%
#
# sphinx-3.2.1         | 1.1 MB    |            |   0%
# sphinx-3.2.1         | 1.1 MB    | ####5      |  46%
# sphinx-3.2.1         | 1.1 MB    | ########## | 100%
# sphinx-3.2.1         | 1.1 MB    | ########## | 100%
#
# setuptools-50.3.1    | 730 KB    |            |   0%
# setuptools-50.3.1    | 730 KB    | #######    |  70%
# setuptools-50.3.1    | 730 KB    | ########## | 100%
# setuptools-50.3.1    | 730 KB    | ########## | 100%
#
# numpydoc-1.1.0       | 42 KB     |            |   0%
# numpydoc-1.1.0       | 42 KB     | ########## | 100%
# numpydoc-1.1.0       | 42 KB     | ########## | 100%
#
# prompt_toolkit-3.0.8 | 12 KB     |            |   0%
# prompt_toolkit-3.0.8 | 12 KB     | ########## | 100%
# prompt_toolkit-3.0.8 | 12 KB     | ########## | 100%
#
# cython-0.29.21       | 1.8 MB    |            |   0%
# cython-0.29.21       | 1.8 MB    | ###3       |  33%
# cython-0.29.21       | 1.8 MB    | #######5   |  76%
# cython-0.29.21       | 1.8 MB    | ########## | 100%
# cython-0.29.21       | 1.8 MB    | ########## | 100%
#
# traitlets-5.0.5      | 83 KB     |            |   0%
# traitlets-5.0.5      | 83 KB     | ########## | 100%
# traitlets-5.0.5      | 83 KB     | ########## | 100%
#
# ipywidgets-7.5.1     | 98 KB     |            |   0%
# ipywidgets-7.5.1     | 98 KB     | ########## | 100%
# ipywidgets-7.5.1     | 98 KB     | ########## | 100%
#
# zope.event-4.5.0     | 210 KB    |            |   0%
# zope.event-4.5.0     | 210 KB    | ########## | 100%
# zope.event-4.5.0     | 210 KB    | ########## | 100%
#
# terminado-0.9.1      | 27 KB     |            |   0%
# terminado-0.9.1      | 27 KB     | ########## | 100%
# terminado-0.9.1      | 27 KB     | ########## | 100%
#
# blosc-1.20.1         | 142 KB    |            |   0%
# blosc-1.20.1         | 142 KB    | ########## | 100%
# blosc-1.20.1         | 142 KB    | ########## | 100%
#
# pydocstyle-5.1.1     | 38 KB     |            |   0%
# pydocstyle-5.1.1     | 38 KB     | ########## | 100%
# pydocstyle-5.1.1     | 38 KB     | ########## | 100%
#
# pygments-2.7.2       | 674 KB    |            |   0%
# pygments-2.7.2       | 674 KB    | ########## | 100%
# pygments-2.7.2       | 674 KB    | ########## | 100%
#
# attrs-20.3.0         | 43 KB     |            |   0%
# attrs-20.3.0         | 43 KB     | ########## | 100%
# attrs-20.3.0         | 43 KB     | ########## | 100%
#
# chardet-3.0.4        | 194 KB    |            |   0%
# chardet-3.0.4        | 194 KB    | ########## | 100%
# chardet-3.0.4        | 194 KB    | ########## | 100%
#
# paramiko-2.7.2       | 143 KB    |            |   0%
# paramiko-2.7.2       | 143 KB    | ########## | 100%
# paramiko-2.7.2       | 143 KB    | ########## | 100%
#
# conda-4.9.2          | 2.9 MB    |            |   0%
# conda-4.9.2          | 2.9 MB    | ##5        |  26%
# conda-4.9.2          | 2.9 MB    | #####4     |  54%
# conda-4.9.2          | 2.9 MB    | ########4  |  84%
# conda-4.9.2          | 2.9 MB    | ########## | 100%
#
# pylint-2.6.0         | 462 KB    |            |   0%
# pylint-2.6.0         | 462 KB    | ########## | 100%
# pylint-2.6.0         | 462 KB    | ########## | 100%
#
# qtawesome-1.0.1      | 757 KB    |            |   0%
# qtawesome-1.0.1      | 757 KB    | ########   |  80%
# qtawesome-1.0.1      | 757 KB    | ########## | 100%
#
# xlsxwriter-1.3.7     | 108 KB    |            |   0%
# xlsxwriter-1.3.7     | 108 KB    | #4         |  15%
# xlsxwriter-1.3.7     | 108 KB    | ########## | 100%
# xlsxwriter-1.3.7     | 108 KB    | ########## | 100%
#
# pandoc-2.11          | 14.4 MB   |            |   0%
# pandoc-2.11          | 14.4 MB   | 3          |   4%
# pandoc-2.11          | 14.4 MB   | 8          |   8%
# pandoc-2.11          | 14.4 MB   | #4         |  14%
# pandoc-2.11          | 14.4 MB   | ##         |  20%
# pandoc-2.11          | 14.4 MB   | ##6        |  26%
# pandoc-2.11          | 14.4 MB   | ###2       |  32%
# pandoc-2.11          | 14.4 MB   | ###7       |  37%
# pandoc-2.11          | 14.4 MB   | ####3      |  43%
# pandoc-2.11          | 14.4 MB   | ####8      |  49%
# pandoc-2.11          | 14.4 MB   | #####3     |  54%
# pandoc-2.11          | 14.4 MB   | #####9     |  60%
# pandoc-2.11          | 14.4 MB   | ######5    |  65%
# pandoc-2.11          | 14.4 MB   | #######    |  71%
# pandoc-2.11          | 14.4 MB   | #######6   |  76%
# pandoc-2.11          | 14.4 MB   | ########1  |  82%
# pandoc-2.11          | 14.4 MB   | ########7  |  88%
# pandoc-2.11          | 14.4 MB   | #########3 |  94%
# pandoc-2.11          | 14.4 MB   | #########9 |  99%
# pandoc-2.11          | 14.4 MB   | ########## | 100%
#
# win_inet_pton-1.1.0  | 35 KB     |            |   0%
# win_inet_pton-1.1.0  | 35 KB     | ########## | 100%
# win_inet_pton-1.1.0  | 35 KB     | ########## | 100%
#
# matplotlib-3.3.2     | 25 KB     |            |   0%
# matplotlib-3.3.2     | 25 KB     | ########## | 100%
# matplotlib-3.3.2     | 25 KB     | ########## | 100%
#
# brotlipy-0.7.0       | 412 KB    |            |   0%
# brotlipy-0.7.0       | 412 KB    | ########## | 100%
# brotlipy-0.7.0       | 412 KB    | ########## | 100%
#
# lz4-c-1.9.2          | 106 KB    |            |   0%
# lz4-c-1.9.2          | 106 KB    | ########## | 100%
# lz4-c-1.9.2          | 106 KB    | ########## | 100%
#
# numba-0.51.2         | 3.1 MB    |            |   0%
# numba-0.51.2         | 3.1 MB    | ##5        |  26%
# numba-0.51.2         | 3.1 MB    | ####8      |  49%
# numba-0.51.2         | 3.1 MB    | #######9   |  80%
# numba-0.51.2         | 3.1 MB    | ########## | 100%
# numba-0.51.2         | 3.1 MB    | ########## | 100%
#
# scipy-1.5.2          | 11.9 MB   |            |   0%
# scipy-1.5.2          | 11.9 MB   | 3          |   4%
# scipy-1.5.2          | 11.9 MB   | 9          |   9%
# scipy-1.5.2          | 11.9 MB   | #7         |  18%
# scipy-1.5.2          | 11.9 MB   | ##3        |  23%
# scipy-1.5.2          | 11.9 MB   | ###        |  31%
# scipy-1.5.2          | 11.9 MB   | ###8       |  38%
# scipy-1.5.2          | 11.9 MB   | ####4      |  45%
# scipy-1.5.2          | 11.9 MB   | #####2     |  52%
# scipy-1.5.2          | 11.9 MB   | #####8     |  58%
# scipy-1.5.2          | 11.9 MB   | ######4    |  65%
# scipy-1.5.2          | 11.9 MB   | #######    |  71%
# scipy-1.5.2          | 11.9 MB   | #######7   |  78%
# scipy-1.5.2          | 11.9 MB   | ########3  |  84%
# scipy-1.5.2          | 11.9 MB   | #########1 |  91%
# scipy-1.5.2          | 11.9 MB   | #########8 |  99%
# scipy-1.5.2          | 11.9 MB   | ########## | 100%
#
# pysocks-1.7.1        | 31 KB     |            |   0%
# pysocks-1.7.1        | 31 KB     | ########## | 100%
# pysocks-1.7.1        | 31 KB     | ########## | 100%
#
# jupyterlab-2.2.6     | 3.4 MB    |            |   0%
# jupyterlab-2.2.6     | 3.4 MB    | #6         |  16%
# jupyterlab-2.2.6     | 3.4 MB    | ###2       |  33%
# jupyterlab-2.2.6     | 3.4 MB    | #####      |  51%
# jupyterlab-2.2.6     | 3.4 MB    | ########8  |  89%
# jupyterlab-2.2.6     | 3.4 MB    | ########## | 100%
#
# pkginfo-1.6.1        | 60 KB     |            |   0%
# pkginfo-1.6.1        | 60 KB     | ########## | 100%
# pkginfo-1.6.1        | 60 KB     | ########## | 100%
#
# ipython-7.19.0       | 998 KB    |            |   0%
# ipython-7.19.0       | 998 KB    | ####9      |  50%
# ipython-7.19.0       | 998 KB    | ########## | 100%
# ipython-7.19.0       | 998 KB    | ########## | 100%
#
# ca-certificates-2020 | 122 KB    |            |   0%
# ca-certificates-2020 | 122 KB    | ########## | 100%
# ca-certificates-2020 | 122 KB    | ########## | 100%
#
# nbclient-0.5.1       | 58 KB     |            |   0%
# nbclient-0.5.1       | 58 KB     | ########## | 100%
# nbclient-0.5.1       | 58 KB     | ########## | 100%
#
# psutil-5.7.2         | 351 KB    |            |   0%
# psutil-5.7.2         | 351 KB    | ########## | 100%
# psutil-5.7.2         | 351 KB    | ########## | 100%
#
# sphinxcontrib-websup | 34 KB     |            |   0%
# sphinxcontrib-websup | 34 KB     | ########## | 100%
# sphinxcontrib-websup | 34 KB     | ########## | 100%
#
# scikit-image-0.17.2  | 8.9 MB    |            |   0%
# scikit-image-0.17.2  | 8.9 MB    | 6          |   7%
# scikit-image-0.17.2  | 8.9 MB    | #4         |  15%
# scikit-image-0.17.2  | 8.9 MB    | ##3        |  24%
# scikit-image-0.17.2  | 8.9 MB    | ###3       |  34%
# scikit-image-0.17.2  | 8.9 MB    | ####3      |  44%
# scikit-image-0.17.2  | 8.9 MB    | #####3     |  53%
# scikit-image-0.17.2  | 8.9 MB    | ######3    |  63%
# scikit-image-0.17.2  | 8.9 MB    | #######2   |  72%
# scikit-image-0.17.2  | 8.9 MB    | ########   |  81%
# scikit-image-0.17.2  | 8.9 MB    | ########9  |  90%
# scikit-image-0.17.2  | 8.9 MB    | ########## | 100%
# scikit-image-0.17.2  | 8.9 MB    | ########## | 100%
#
# zipp-3.4.0           | 15 KB     |            |   0%
# zipp-3.4.0           | 15 KB     | ########## | 100%
# zipp-3.4.0           | 15 KB     | ########## | 100%
#
# pexpect-4.8.0        | 53 KB     |            |   0%
# pexpect-4.8.0        | 53 KB     | ########## | 100%
# pexpect-4.8.0        | 53 KB     | ########## | 100%
#
# certifi-2020.11.8    | 148 KB    |            |   0%
# certifi-2020.11.8    | 148 KB    | ########## | 100%
# certifi-2020.11.8    | 148 KB    | ########## | 100%
#
# colorama-0.4.4       | 18 KB     |            |   0%
# colorama-0.4.4       | 18 KB     | ########## | 100%
# colorama-0.4.4       | 18 KB     | ########## | 100%
#
# kiwisolver-1.3.0     | 78 KB     |            |   0%
# kiwisolver-1.3.0     | 78 KB     | ########## | 100%
# kiwisolver-1.3.0     | 78 KB     | ########## | 100%
#
# autopep8-1.5.4       | 42 KB     |            |   0%
# autopep8-1.5.4       | 42 KB     | ########## | 100%
# autopep8-1.5.4       | 42 KB     | ########## | 100%
#
# distributed-2.30.1   | 1.0 MB    |            |   0%
# distributed-2.30.1   | 1.0 MB    | ######1    |  62%
# distributed-2.30.1   | 1.0 MB    | ########## | 100%
# distributed-2.30.1   | 1.0 MB    | ########## | 100%
#
# iniconfig-1.1.1      | 9 KB      |            |   0%
# iniconfig-1.1.1      | 9 KB      | ########## | 100%
# iniconfig-1.1.1      | 9 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      63   try:
# ---> 64     from tensorflow.python._pywrap_tensorflow_internal import *
#      65   # This try catch logic is because there is no bazel equivalent for py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-64156d691fe5> in <module>
# ----> 1 import tensorflow as tf
#
# ~\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      38 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      39
# ---> 40 from tensorflow.python.eager import context
#      41
#      42 # pylint: enable=wildcard-import
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in <module>
#      33 from tensorflow.core.protobuf import config_pb2
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
# ---> 35 from tensorflow.python import pywrap_tfe
#      36 from tensorflow.python import tf2
#      37 from tensorflow.python.client import pywrap_tf_session
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tfe.py in <module>
#      26
#      27 # pylint: disable=invalid-import-order,g-bad-import-order, wildcard-import, unused-import
# ---> 28 from tensorflow.python import pywrap_tensorflow
#      29 from tensorflow.python._pywrap_tfe import *
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      81 for some common reasons and solutions.  Include the entire stack trace
#      82 above this error message when asking for help.""" % traceback.format_exc()
# ---> 83   raise ImportError(msg)
#      84
#      85 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\gogog\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 64, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      63   try:
# ---> 64     from tensorflow.python._pywrap_tensorflow_internal import *
#      65   # This try catch logic is because there is no bazel equivalent for py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ~\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#
# ~\anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      39
# ---> 40 from tensorflow.python.eager import context
#      41
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in <module>
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
# ---> 35 from tensorflow.python import pywrap_tfe
#      36 from tensorflow.python import tf2
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tfe.py in <module>
#      27 # pylint: disable=invalid-import-order,g-bad-import-order, wildcard-import, unused-import
# ---> 28 from tensorflow.python import pywrap_tensorflow
#      29 from tensorflow.python._pywrap_tfe import *
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      82 above this error message when asking for help.""" % traceback.format_exc()
# ---> 83   raise ImportError(msg)
#      84
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\gogog\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 64, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-b9e2c8277ae4> in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense
#
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#       3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
# ----> 5     raise ImportError(
#       6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

# %%
# Random seed for reproducibility
numpy.random.seed(7)

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.3
